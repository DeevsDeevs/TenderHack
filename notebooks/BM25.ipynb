# %%
# %load_ext autoreload
# %autoreload 2

# %%
import ast
import pandas as pd
import numpy as np
import pymorphy2
import json
from rank_bm25 import BM25Okapi
from tqdm import tqdm

# %%
tqdm.pandas()

# %%
df = pd.read_feather("data/goods.feather")

# %%
def standardization_characteristics(characteristics: str):
    if characteristics is None:
        return ""
    characteristics = ast.literal_eval(characteristics.lower())
    data = []
    for characteristic in characteristics:
        if "value" in characteristic:
            if len(characteristic["value"].split()) <= 3:
                if ("value" in characteristic) and ("unit" in characteristic):
                    data.append(f"{characteristic['value']} {characteristic['unit']}")
                elif characteristic["value"] in ["да", "нет"]:
                    if len(characteristic["name"].split()) <= 3:
                        data.append(characteristic['name'])
                else:
                    data.append(characteristic["value"])
    return ", ".join(list({i.strip() for i in data}))

# %%
df = df.drop(df.index[[126302, 170141]])

# %%
df['feat_text'] = df['Характеристики'].progress_apply(lambda s: standardization_characteristics(s))
# Out:
# 100%|██████████| 356573/356573 [00:37<00:00, 9411.31it/s]

# %%
df["text"] = df["Название СТЕ"].str.lower().str.strip() +  " [SEP] " + df["Характеристики"].str.strip()

# %%
df["cat_count"] = df.groupby('Категория')['Категория'].transform('count')

# %%
df["text25"] = df["Название СТЕ"] + " " + df["Категория"]

# %%
df["text25"].to_list()
# Out:
# ['мяч футбольный MIKASA REGATEADOR5-G Мячи футбольные',
#  'мяч волейбольный Gala Pro-Line 10 FIVB Мячи волейбольные ',
#  'мяч волейбольный Mikasa MVA380K-OBL Мячи волейбольные ',
#  'мяч волейбольный Wilson Super Soft Play Мячи волейбольные ',
#  'Gutrend комплект расходных материалов для FUN 110 Pet Расходные материалы, комплектующие для прочего бытового оборудования',
#  'Neolux FSM-05 набор фильтров для пылесоса Samsung Фильтр для пылесоса',
#  'Jura 62536 жидкость для чистки автокаппучинатора, 1 л Расходные материалы, комплектующие для прочего бытового оборудования',
#  'Karcher AD 3.200 1.629-662.0 промышленный пылесос Пылесос',
#  'Vitek VT-1886(B) пылесос Пылесос',
#  'Philips FC8471/01 PowerPro Compact безмешковый компактный\xa0 пылесос Пылесос',
#  'Philips FC9170/02 пылесос Пылесос',
#  'Midea VCB33A1 пылесос Пылесос',
#  'Scarlett SC-VC80B07, Red пылесос Пылесос',
#  'Samsung SC-20M257AWR пылесос Пылесос',
#  'Samsung SC-885HH3P пылесос Пылесос',
#  'Polaris PVC 1730СR, Red пылесос Пылесос',
#  'Samsung VCJG24LV пылесос Пылесос',
#  'Samsung SC-4326 пылесос Пылесос',
#  'Samsung VC18M21D0VG, Black пылесос Пылесос',
#  'LG VK76W02HY пылесос Пылесос',
#  'Thomas 785037 Multi Cyclone Pro 14, Black пылесос Пылесос',
#  'Polaris PVC 1820G пылесос Пылесос',
#  'Samsung SC-18M2110SB пылесос Пылесос',
#  'Philips FC9352/01 PowerPro Compact безмешковый компактный\xa0 пылесос Пылесос',
#  'Samsung SC-18M3160VG пылесос Пылесос',
#  'Scarlett SC-VC80C03, Sky Blue пылесос Пылесос',
#  'Samsung SC-18M31A0HP пылесос Пылесос',
#  'Karcher SE 4002 1.081-140.0 моющий пылесос Пылесос',
#  'Thomas 788565 Twin XT пылесос Пылесос',
#  'Bosch BCH6ATH18 пылесос Пылесос',
#  'Нитевдеватель "Prym" для вышивки Принадлежности для шитья и рукоделия металлические',
#  'Иглы для швейных машин "Арт",№ 80, уп.10шт, 162194 Иглы для швейных машин',
#  'Иглы для бытовых швейных машин Иглы Арти "0220-01", для джинсы, №90, 5 шт Принадлежности для шитья и рукоделия металлические',
#  'Иглы для промышленных швейных машин "Organ", DCx27/90, 10 шт Принадлежности для шитья и рукоделия металлические',
#  'Иглы для швейных машин "Иглы Арти", универсальные, №80, 5 шт Иглы для швейных машин',
#  'Иглы для швейных машин "Иглы Арти", универсальные, №90, 5 шт Иглы для швейных машин',
#  'Иглы для промышленных швейных машин Иглы Арти "0277-02", №80, 10 шт Принадлежности для шитья и рукоделия металлические',
#  'Иглы для швейных машин "Иглы Арти", универсальные, №100, 5 шт Иглы для швейных машин',
#  'Иглы для швейных машин "Иглы Арти", для кожи, №100, 5 шт Иглы для швейных машин',
#  'Иглы для швейных машин "Иглы Арти", для трикотажа, №80, 5 шт Иглы для швейных машин',
#  'Иглы для бытовых швейных машин Organ "Blue tip janome", №75, 5 шт.162250 Принадлежности для шитья и рукоделия металлические',
#  'Иглы для швейных машин "Иглы Арти", для трикотажа, №90, 5 шт Иглы для швейных машин',
#  'Набор универсальных игл для швейных машин "Organ", №100, 5 шт Принадлежности для шитья и рукоделия металлические',
#  'Иглы для швейных машин "Organ", универсальные, № 80, 10 шт Иглы для швейных машин',
#  'Иглы для промышленных швейных машин "Organ", DBx1/80, 10 шт Принадлежности для шитья и рукоделия металлические',
#  'Иглы для бытовых швейных машин Иглы Арти "0220-06", № 90, стрейч , 5 шт Принадлежности для шитья и рукоделия металлические',
#  'Набор универсальных игл "Schmetz", №100, 10 шт Принадлежности для шитья и рукоделия металлические',
#  'Набор универсальных игл "Schmetz", №100, 5 шт Принадлежности для шитья и рукоделия металлические',
#  'Иглы для бытовых швейных машин "Schmetz", универсальные, №120, 5 шт Принадлежности для шитья и рукоделия металлические',
#  'Иглы для бытовых швейных машин "Schmetz", универсальные, легковдеваемые, №80, 5 шт Принадлежности для шитья и рукоделия металлические',
#  'Набор универсальных игл "Schmetz", №80, 10 шт Принадлежности для шитья и рукоделия металлические',
#  'Набор универсальных игл "Schmetz", №90, 5 шт Принадлежности для шитья и рукоделия металлические',
#  'Иглы для бытовых швейных машин "Schmetz", универсальные, №70,80, 90, 5 шт Принадлежности для шитья и рукоделия металлические',
#  'Иглы для бытовых швейных машин "Schmetz", универсальные, №80, 90, 100, 5 шт Принадлежности для шитья и рукоделия металлические',
#  'Нитковдеватель "Hemline", 2 шт Принадлежности для шитья и рукоделия металлические',
#  'Jaguar 055D оверлок Оверлоки',
#  'Janome Juno 5025S швейная машина Швейная машина',
#  'Brother NV950, White швейно-вышивальная машина Швейная машина',
#  'Janome DC 50 швейная машина Швейная машина',
#  'Janome 419S швейная машина Швейная машина',
#  'Janome My Excel 1221 швейная машина Швейная машина',
#  'Janome SE 522 швейная машина Швейная машина',
#  'Janome Jem швейная машина Швейная машина',
#  'Janome DC4030, White швейная машина Швейная машина',
#  'Brother Classic 40 швейная машина Швейная машина',
#  'Janome 2020 швейная машина Швейная машина',
#  'Janome 210D оверлок Оверлоки',
#  'Janome Cover Pro 2 распошивальная машина Швейная машина',
#  'Juki MO 654 D оверлок Оверлоки',
#  'Brother 3034D оверлок Оверлоки',
#  'Janome MS 100 швейная машина Швейная машина',
#  'Comfort 110 /140 оверлок 2/3/4-х ниточный Оверлоки',
#  'Brother M14 швейная машина Швейная машина',
#  'Singer Heavy Duty 4423 швейная машина Швейная машина',
#  'Brother LX500 швейная машина Швейная машина',
#  'Janome Т-34 оверлок Оверлоки',
#  'Singer Confidence 7640 Q швейная машина Швейная машина',
#  'Philips GC1026/30 утюг Утюги электрические бытовые',
#  'Maxwell MW-3052 (VT) утюг Утюги электрические бытовые',
#  'Philips GC1436/20, Blue утюг Утюги электрические бытовые',
#  'Philips PerfectCare Azur GC4922/80 утюг с OptimalTemp Утюги электрические бытовые',
#  'Unit USI-280, Blue утюг Утюги электрические бытовые',
#  'Scarlett SC-SI30K22, Blue утюг Утюги электрические бытовые',
#  'MIE Stiro 1200 парогенератор Утюги электрические бытовые',
#  'Maxwell MW-3042(VT) утюг Утюги электрические бытовые',
#  'Makita HR2600 перфоратор Перфораторы',
#  'Вихрь ДУ-1100 дрель ударная Дрели ручные электрические',
#  'Makita HP2071 дрель ударная Дрели ручные электрические',
#  'Makita HR2460 Перфораторы',
#  'Makita 6408, дрель Дрели ручные электрические',
#  'Перфоратор Makita HR2470FT Перфораторы',
#  'Дрель-шуруповерт Вихрь ДА-14,4-2, аккумуляторная Шуруповерты',
#  'Makita HR4511C перфоратор SDS Max Перфораторы',
#  'Перфоратор Makita HR2470 Перфораторы',
#  'Отбойный молоток Makita HM1203C Инструмент электрический и моторизованный прочий',
#  'Перфоратор Makita HR5211С Перфораторы',
#  'Ударный шуруповерт Makita TD0101 Шуруповерты',
#  'Дрель ударная Makita HP2070 Дрели ручные электрические',
#  'Makita HR4501C перфоратор Перфораторы',
#  'Bosch PBH 2100 RE (06033A9320) перфоратор Перфораторы',
#  'Молоток отбойный Makita HM 0870C Инструмент электрический и моторизованный прочий',
#  'Дрель безударная Makita 6413 Дрели ручные электрические',
#  'Makita HR5001C перфоратор Перфораторы',
#  'Makita FS6300 шуруповерт Шуруповерты',
#  'Дрель-шуруповерт аккумуляторная FIT CD-14LC Шуруповерты',
#  'Дрель ударная Makita HP1630 Дрели ручные электрические',
#  'Makita HR5201C перфоратор Перфораторы',
#  'Hitachi UM12VST миксер Инструмент электрический и моторизованный прочий',
#  'Ударная дрель Bosch GSB 13 RE Дрели ручные электрические',
#  'Перфоратор Bosch GBH 2-26 DRE Перфораторы',
#  'Дрель DeWalt DWD112S Дрели ручные электрические',
#  'Makita HR3200C перфоратор SDS Plus Перфораторы',
#  'Перфоратор Bosch GBH 2-26 DFR Перфораторы',
#  'Шуруповерт Bosch PSR 1440 LI-2 (06039A3021) Шуруповерты',
#  'Ударная дрель Bosch GSB 16 RE Дрели ручные электрические',
#  'Дрель ударная Makita HP1640 Дрели ручные электрические',
#  'Дрель ударная Black&Decker KR604CRES Дрели ручные электрические',
#  'Ударная дрель Bosch GSB 1600 RE Дрели ручные электрические',
#  'Отвертка аккумуляторная Bort BAS-48N-Lt Шуруповерты',
#  'Дрель аккумуляторная Makita DDF453RFE Шуруповерты',
#  'Перфоратор Вихрь П-800к-в Перфораторы',
#  'Hitachi DS18DVF3-TA шуруповерт Шуруповерты',
#  'Makita HR2300 перфоратор SDS Plus Перфораторы',
#  'Миксер строительный Hammer Flex MXR1400A Инструмент электрический и моторизованный прочий',
#  'Перфоратор Вихрь П-900к Перфораторы',
#  'Makita DP4001 дрель Дрели ручные электрические',
#  'Аккумуляторный шуруповерт Bosch IXO V MEDIUM Шуруповерты',
#  'Makita DP4003 дрель Дрели ручные электрические',
#  'Дрель ударная Интерскол ДУ-16/1000ЭР Дрели ручные электрические',
#  'Makita DP4010 дрель Дрели ручные электрические',
#  'Дрель ударная Интерскол ДУ-13/780ЭР Дрели ручные электрические',
#  'Makita DP4011 дрель Дрели ручные электрические',
#  'Интерскол ДУ-13/810ЭР Дрели ручные электрические',
#  'Hyundai H 800 Expert перфоратор Перфораторы',
#  'Дрель-шуруповерт Makita DF030DWE, аккумуляторная Шуруповерты',
#  'Дрель ударная ЗУБР ЗДУ-780 ЭРКМ2 Дрели ручные электрические',
#  'Интерскол КМ-60/1000Э Инструмент электрический и моторизованный прочий',
#  'Makita FS4000 шуруповерт Шуруповерты',
#  'Дрель ударная ДУ-850 (ДУ-750) Вихрь Дрели ручные электрические',
#  'Дрель-шуруповерт Defort "DCD-12N-7-B", аккумуляторная Шуруповерты',
#  'Дрель ударная ЗУБР ЗДУ-850 ЭРММ2 Дрели ручные электрические',
#  'Дрель-шуруповерт ЗУБР ЗСШ-300-2, сетевая Шуруповерты',
#  'Дрель-шуруповерт аккумуляторная Ставр "ДА-12" Шуруповерты',
#  'Дрель-шуруповерт аккумуляторная Bosch "PSR 1440 LI-2" Шуруповерты',
#  'Дрель-шуруповерт аккумуляторная Bort "BAB-10,8NX2LI-FDK" Шуруповерты',
#  'Шуруповерт RedVerg "RD-SD14L/2", аккумуляторный Шуруповерты',
#  'Миксер Hammer "Flex MXR1400" Инструмент электрический и моторизованный прочий',
#  'Дрель-миксер BPM-1400x2 Дрели ручные электрические',
#  'Дрель-шуруповерт аккумуляторная Кратон "CD-18-K" Шуруповерты',
#  'Дрель ударная ЗУБР "Мастер", 810 Вт Дрели ручные электрические',
#  'Дрель-шуруповерт Вихрь "ДА-12-1", аккумуляторная Шуруповерты',
#  'Дрель-шуруповерт Вихрь "ДА-12Л-2К", аккумуляторная Шуруповерты',
#  'Дрель-шуруповерт Вихрь "ДА-14,4Л-2К", аккумуляторная Шуруповерты',
#  'Дрель-шуруповерт "Калибр", аккумуляторная. ДА-12/2+Н550 Шуруповерты',
#  'Дрель-шуруповерт Вихрь "ДА-18Л-2К", аккумуляторная Шуруповерты',
#  'Дрель-шуруповерт аккумуляторная Metabo "BS 18 LTX Impuls" Шуруповерты',
#  'Дрель-шуруповерт аккумуляторная Bosch "GSR 120-Li" Шуруповерты',
#  'Шуруповерт аккумуляторный Metabo "PowerMaxx BS Quick Basic" Шуруповерты',
#  'Дрель-шуруповерт аккумуляторная Metabo "BS 18" Шуруповерты',
#  'Дрель-шуруповерт аккумуляторная Bosch "GSR 12V-15 FC". 06019F6001 Шуруповерты',
#  'Миксер строительный "Stanley". SDR1400 Инструмент электрический и моторизованный прочий',
#  'Дрель-шуруповерт "Stanley" аккумуляторная, ударная. SCH201D2K Шуруповерты',
#  'Дрель ударная Bosch "EasyImpact 550" Дрели ручные электрические',
#  'Перфоратор Bosch "GBH 2-28 New". 0611267500 Перфораторы',
#  'Дрель-шуруповерт аккумуляторная "DeWalt". DCD710C2 Шуруповерты',
#  'Дрель-шуруповерт аккумуляторная "Makita". DF331DWME Шуруповерты',
#  'Дрель-шуруповерт аккумуляторная Интерскол "Домашний мастер". ДА-12ЭР-01 Шуруповерты',
#  'Шуруповерт аккумуляторный DeWalt DCD776S2 Шуруповерты',
#  'Дрель-шуруповерт аккумуляторная "DeWalt", ударная. DCD737P2 Шуруповерты',
#  'Дрель ударная Bosch "UniversalImpact 700". 0603131020 Дрели ручные электрические',
#  'Насадка-миксер строительная Vorel "Турбо", диаметр 8 см Рабочие органы сменные прочие (оснастка для инструментов)',
#  'Дрель-шуруповерт аккумуляторная "DeWalt". DCD710D2 Шуруповерты',
#  'Шуруповерт аккумуляторный "DeWalt". DCD771S2 Шуруповерты',
#  'Миксер для краски "Vorel", 8,5 x 40 см Рабочие органы сменные прочие (оснастка для инструментов)',
#  ' Аккумуляторная ударная дрель-шуруповерт DEWALT DCD796D2 Шуруповерты',
#  'Шуруповерт аккумуляторный DeWalt "DCD791D2" Шуруповерты',
#  'Миксер для вязких строительных смесей и клея "Vorel" Рабочие органы сменные прочие (оснастка для инструментов)',
#  'Шуруповерт аккумуляторный Metabo "BS\xa018". 602207500 Шуруповерты',
#  'Дрель-шуруповерт аккумуляторная Bosch "GSR 180-Li", 2 аккумулятора Шуруповерты',
#  'Миксер оцинкованный Vorel "Турбо", C-110 Рабочие органы сменные прочие (оснастка для инструментов)',
#  'Дрель ударная Metabo "SBE\xa0650". 600671510 Дрели ручные электрические',
#  'Аккумуляторный винтоверт Metabo "PowerMaxx BS Basic" Инструмент электрический и моторизованный прочий',
#  'Дрель ударная "DeWalt". DWD024S Дрели ручные электрические',
#  'Шуруповерт аккумуляторный Metabo "BS 14.4" Шуруповерты',
#  'Дрель аккумуляторная ударная Bosch "EasyImpact 12" Шуруповерты',
#  'Перфоратор DeWalt "SDS Plus". D25134K Перфораторы',
#  'Перфоратор Metabo "KHE\xa02660 SDS+". 600663500 Перфораторы',
#  'Аккумуляторная дрель Hammer Flex ACD120GLi Шуруповерты',
#  'Перфоратор Metabo "KHE\xa02860 SDS+". 600878510 Перфораторы',
#  'Аккумуляторный перфоратор Bosch GBH 180-Li, 2 АКБ. 0611911023 Перфораторы',
#  'Дрель-шуруповерт аккумуляторная Bort "BAB-18Ux2Li-FDK" Шуруповерты',
#  'Вибрационная шлифмашина Bosch PSS 250 AE PSS 250 AE Шлифмашины',
#  'Шлифмашина угловая Makita 9069SF Шлифмашины',
#  'Шлифмашина угловая Makita 9069 F Шлифмашины',
#  'Шлифмашина угловая Makita GA9020 Шлифмашины',
#  'Шлифмашина угловая Makita 9069 Шлифмашины',
#  'Шлифмашина вибрационная Makita BO3710 Шлифмашины',
#  'Шлифмашина эксцентриковая  BO 5030 Шлифмашины',
#  'Шлифмашина эксцентриковая  BO5031 Шлифмашины',
#  'Шлифмашина эксцентриковая DeWalt D26410 Шлифмашины',
#  'Шлифмашина угловая Интерскол УШМ-150/1300 Шлифмашины',
#  'Шлифмашина угловая Makita GA4530 Шлифмашины',
#  'Шлифмашина угловая Интерскол УШМ-180/1800М Шлифмашины',
#  'Шлифмашина угловая Makita 9558HNK Шлифмашины',
#  'Шлифмашина угловая Makita GA5030 Шлифмашины',
#  'Шлифмашина угловая Makita GA9020SF Шлифмашины',
#  'Шлифмашина вибрационная Makita BO3711 Шлифмашины',
#  'Kitfort КТ-1310 блендер Блендер',
#  'Bosch MSM2610B, Black блендер Блендер',
#  'Irit IR-5512, Purple блендер Блендер',
#  'Bosch MFQ 4020 миксер Миксер',
#  'Smile MS 754 миксер для молока Миксер',
#  'Galaxy GL 2206 миксер Миксер',
#  'Galaxy GL 2210 миксер Миксер',
#  'Polaris PHM 5009A миксер Миксер',
#  'Bosch MMR15A1 измельчитель Блендер',
#  'Russell Hobbs 22281-56 Aura Slice & Go овощерезка Ломтерезки',
#  "Tefal PY6044 Блинница Crep'Party Dual Блинницы",
#  'Maxwell MW-1571 вафельница Блинницы',
#  'Tristar BP-2634, Black блинница Блинницы',
#  'Redmond RMB-M603 мультипекарь Блинницы',
#  'Tefal PY 3036 33 блинница Блинницы',
#  'Moulinex SW611812 сэндвичница Сэндвичницы',
#  'Bosch MUM 4855 кухонный комбайн Кухонный комбайн',
#  'Braun FP5150WH кухонный комбайн Кухонный комбайн',
#  'Vitek VT-1506(BK) кофеварка Электрокофеварки бытовые',
#  'Redmond RCM-M1507 кофеварка Электрокофеварки бытовые',
#  'DeLonghi EN 126 Nespresso Pixie Clips кофеварка Электрокофеварки бытовые',
#  'Tefal CM361E38 кофеварка Электрокофеварки бытовые',
#  'Philips HD8649/51 кофемашина Электрокофеварки бытовые',
#  'DeLonghi Magnifica ECAM 22.110.SB, кофемашина Электрокофеварки бытовые',
#  'DeLonghi Autentica ETAM 29.660.SB кофемашина Электрокофеварки бытовые',
#  'DeLonghi Magnifica ECAM 22.110.B кофемашина Электрокофеварки бытовые',
#  'DeLonghi ETAM29.510.SB кофемашина Электрокофеварки бытовые',
#  'DeLonghi Dinamica ECAM 350.15.B кофемашина Электрокофеварки бытовые',
#  'DeLonghi Nespresso Pixie Clips EN 126 капсульная кофемашина Электрокофеварки бытовые',
#  'Kitfort КТ-1315 кофемолка Кофемолка',
#  'Profi Cook PC-KW 1061 кухонные весы Весы кухонные',
#  'Maxwell MW-1451, Silver весы кухонные Весы кухонные',
#  'Redmond RS-736 Полоски весы кухонные Весы кухонные',
#  'Irit IR-7118 весы кухонные Весы кухонные',
#  'Scarlett SC-KS57P99, Steel весы кухонные Весы кухонные',
#  'Polaris PKS 1046DG Cherry кухонные весы Весы кухонные',
#  'Starwind SSK3354, Brown Red Blue весы кухонные Весы кухонные',
#  'Lumme LU-1340 "Ягодный микс" весы кухонные Весы кухонные',
#  'Samsung ME-83XR СВЧ-печь Микроволновая печь',
#  'Samsung ME81KRW-1 СВЧ-печь Микроволновая печь',
#  'Samsung ME-83KRW-2 СВЧ-печь Микроволновая печь',
#  'BBK 20MWS-704M/W микроволновая печь Микроволновая печь',
#  'LG MH6044V СВЧ-печь Микроволновая печь',
#  'Daewoo KOR-5A17, White Green СВЧ-печь Микроволновая печь',
#  'BBK 20MWS-713M/W, White СВЧ-печь Микроволновая печь',
#  'Samsung MC-28H5013AW СВЧ-печь Микроволновая печь',
#  'Redmond RM-2002D СВЧ-печь Микроволновая печь',
#  'Honeywell ES800\xa0увлажнитель воздуха Очистители и увлажнители воздуха',
#  'Delta DL-023H вентилятор Вентиляторы бытовые',
#  'Maxwell MW-3547(W) вентилятор настольный Вентиляторы бытовые',
#  'Breville P365 вентилятор Вентиляторы бытовые',
#  'First FA-5560-2, Black вентилятор напольный Вентиляторы бытовые',
#  'Бирюса 50 холодильник Холодильники бытовые',
#  'GASTRORAG BCH-40B, Black холодильник Холодильное оборудование',
#  'Славда WS-50PET стиральная машина Машины стиральные бытовые',
#  'Bomann TSG 707, Silver посудомоечная машина Посудомоечная машина',
#  'Ricci RRH-2260-WH вытяжка Вытяжки',
#  'HotFrost стаканодержатель на 70 стаканчиков, Silver Расходные материалы, комплектующие для прочего бытового оборудования',
#  'Vatten V45SE кулер для воды, Silver Кулер',
#  'Vatten V45QE кулер для воды, Champagne Кулер',
#  'HotFrost V118 кулер для воды Кулер',
#  'Vatten V41 WE кулер для воды, White Кулер',
#  'Vatten №3M, Blue механическая помпа для воды Расходные материалы, комплектующие для прочего бытового оборудования',
#  'Aqua Work 16LW/HLN диспенсер для воды Кулер',
#  'Vatten V42 NE, Black кулер для воды Кулер',
#  'Vatten №5, Blue механическая помпа для воды Расходные материалы, комплектующие для прочего бытового оборудования',
#  'Aqua Work 16LD/EN, White кулер для воды Кулер',
#  'Aqua Work 0.7LD кулер для воды Кулер',
#  'Aqua Work 1665S кулер для воды Кулер',
#  'Aqua Work 16LD/HLN кулер для воды Кулер',
#  'Simfer H60D17B011 панель варочная электрическая Плиты электрические бытовые',
#  'Venta термогигрометр Цифровые метеостанции',
#  'Scarlett SC-EK27G18, Black чайник электрический Чайник электрический',
#  'Scarlett SC-EK21S43, Stainless Steel электрический чайник Чайник электрический',
#  'Irit IR-1320 электрический чайник Чайник электрический',
#  'Gemlux GL-K101SS чайник электрический Чайник электрический',
#  'GASTRORAG DK-LX-100 кипятильник Чайник электрический',
#  'GASTRORAG DK-LX-200 кипятильник Чайник электрический',
#  'GASTRORAG DK-PU-100 кипятильник Чайник электрический',
#  'Gemlux GL-WB-200S электрокипятильник Чайник электрический',
#  'Galaxy GL 0318, White электрический чайник Чайник электрический',
#  'Kitfort КТ-621 чайник электрический Чайник электрический',
#  'Kitfort КТ-623 чайник электрический Чайник электрический',
#  'Rommelsbacher GA 1700 термопот Термопоты бытовые',
#  'Rommelsbacher GA 1000 термопот Термопоты бытовые',
#  'Galaxy GL 0606 термопот Термопоты бытовые',
#  'Galaxy GL 0607, Silver термопот Термопоты бытовые',
#  'Galaxy GL 0605 термопот Термопоты бытовые',
#  'Energy TP-617, White термопот Термопоты бытовые',
#  'Galaxy GL 0603 термопот Термопоты бытовые',
#  'Energy TP-617 термопот Термопоты бытовые',
#  'Scarlett SC-ET10D13, Black термопот Термопоты бытовые',
#  'Tefal GC306012 Health Grill Comfort электрогриль Электрогриль',
#  'CASO BG 1000, Black Steel электрогриль Электрогриль',
#  'Philips BHD001/00 фен Фены бытовые',
#  'Remington D5000 Compact 1800 фен Фены бытовые',
#  'Moser Protect, Black фен профессиональный Фены бытовые',
#  'Philips HP8238/00, Black фен Фены бытовые',
#  'AEG HTD 5649 фен Фены бытовые',
#  'Edding Набор маркеров для доски 4 цвета Маркеры',
#  'Stabilo Набор маркеров Boss Original 4 цвета Маркеры',
#  'Faber-Castell Набор маркеров для доски Grip 4 шт Маркеры',
#  'Stabilo Набор маркеров Boss Original 6 цветов Маркеры',
#  'Stabilo Набор маркеров Boss Executive 4 цвета Маркеры',
#  'Brauberg Маркер для доски Neo цвет красный Маркеры',
#  'Berlingo Набор маркеров для доски 4 цвета Маркеры',
#  'Brauberg Маркер для доски Neo цвет синий Маркеры',
#  'Stabilo Маркер перманентный черный Маркеры',
#  'Brauberg Маркер для доски Neo цвет черный Маркеры',
#  'Edding Маркер для доски цвет черный Маркеры',
#  "Maped Набор маркеров Fluo Pep'S Ultra Soft 4 цвета Маркеры",
#  'Vista-Artista Маркер Style цвет океанский зеленый Z416 Маркеры',
#  'Vista-Artista Маркер Style цвет серый теплый 2 S487 Маркеры',
#  'Vista-Artista Маркер Style цвет Z465 светло-хаки Маркеры',
#  'Vista-Artista Маркер Style цвет слоновая кость J101 Маркеры',
#  'Vista-Artista Маркер Style цвет K226 алый Маркеры',
#  'Staedtler Маркер Triplus цвет красный 3451-2 Маркеры',
#  'Vista-Artista Маркер Style цвет B100 черный Маркеры',
#  'Vista-Artista Маркер Style цвет мятно-голубой G343 Маркеры',
#  'Vista-Artista Маркер Style цвет светлый розово-бежевый K247 Маркеры',
#  'Vista-Artista Маркер Style цвет J149 светло-оранжевый Маркеры',
#  'Набор фломастеров "Веселые животные", 18 цветов Фломастеры',
#  'Набор смываемых фломастеров "Centropen", 12 цветов Фломастеры',
#  'Centropen Набор фломастеров Слон 30 цветов Фломастеры',
#  'Набор цветных фломастеров, 12 шт Barbie Фломастеры',
#  'Набор фломастеров POWER MAX 12 цв, пластиковый футляр Фломастеры',
#  'Faber-Castell Фломастеры Jumbo 24 цвета Фломастеры',
#  'Faber-Castell Набор фломастеров 12 шт Фломастеры',
#  'Silwerhof Фломастеры Народная коллекция 18 цветов Фломастеры',
#  'Berlingo Набор фломастеров Жил-был кот 6 цветов Фломастеры',
#  'Berlingo Набор фломастеров Жил-был кот 12 цветов Фломастеры',
#  'Silwerhof Фломастеры Джинсовая коллекция 12 цветов 867209-12 Фломастеры',
#  'Action! Набор фломастеров 6 цветов Фломастеры',
#  'Action! Набор фломастеров 18 цветов Фломастеры',
#  'Berlingo Набор фломастеров Замки 18 цветов Фломастеры',
#  'Micador Фломастеры 12 цветов Фломастеры',
#  'Пифагор Набор фломастеров 6 цветов Фломастеры',
#  'Koh-I-Noor Набор фломастеров Утята 18 цветов Фломастеры',
#  'Maped Набор фломастеров Colorpeps Ocean 18 цветов Фломастеры',
#  'Giotto Набор фломастеров Turbo Color 12 цветов Фломастеры',
#  'Maped Набор двусторонних фломастеров DUO 10 шт 20 цветов Фломастеры',
#  'Maped Набор фломастеров Jungle смываемые 18 цветов Фломастеры',
#  'Faber-Castell Набор фломастеров Connector Машина с клипами 33 цвета Фломастеры',
#  'Тетрадь с твердой обложкой 96л А5ф клетка на гребне LONDON Тетрадь ученическая общая',
#  'Папка для акварели "Kroyter", 10 листов, формат А3. 05688 Папки для рисования',
#  'Папка для рисования и эскизов "Kroyter", 20 листов, формат А3 Папки для рисования',
#  'Бумага масштабно-координатная "Hatber", 8 листов, формат А3. 8Бм3_02285 Бумага миллиметровая (масштабно-координатная) и логарифмическая',
#  'Hatber Набор цветной самоклеящейся бумаги Creative Set 10 листов Самоклеящаяся бумага',
#  'Альбом для рисования с бумагой для акварели Erich Krause "Дом у моря", 20 листов. 37168 Альбомы для рисования',
#  'Цветной картон Hatber "Подводный мир", двусторонний, 10 цветов Картон канцелярский',
#  'Цветная бумага для рукоделия Palazzo "Басня", 30 листов, 10 цветов, формат А4 Бумага цветная для творчества',
#  'Папка для пастели и акварели/планшет А3, 20 листов, 2 цвета, 200 г/м2, тонированная бумага, «Венеция», ПЛ-6457 Папки для рисования',
#  'Milan Набор ластиков 124 цвет зеленый красный 3 шт Ластики',
#  'Staedtler Линейка цвет прозрачный 40 см Линейки',
#  'Faber-Castell Ластик виниловый Dust-Free 187120 Ластики',
#  'Faber-Castell Ластик Dust-Free цвет белый Ластики',
#  'Проф-Пресс Классный журнал для 10-11 классов 92 листа Канцелярские журналы',
#  'ArtSpace Альбом для рисования Мультяшки 20 листов Альбомы для рисования',
#  'Silwerhof Цветная бумага металлизированная Shine Flyers 5 листов 5 цветов Бумага цветная для творчества',
#  'Sadipal Бумага цветная глянцевая 10 листов Бумага цветная для творчества',
#  'Апплика Цветная бумага Пеликан 8 листов Бумага цветная для творчества',
#  'Апплика Цветной картон Медведь 10 листов Картон канцелярский',
#  'Апплика Бумага для черчения Дом 10 листов формат А3 Папки для черчения',
#  'Бриз Бумага цветная двухсторонняя 10 листов Бумага цветная для творчества',
#  'Palazzo Альбом для рисования Белая Роза 20 листов ПЛБР/А2 Альбомы для рисования',
#  'Бриз Бумага цветная двухсторонняя Щенок 16 листов Бумага цветная для творчества',
#  'Апплика Альбом для рисования Париж 24 листа Альбомы для рисования',
#  'Kroyter Альбом для рисования акварелью 40 листов Альбомы для рисования',
#  'Palazzo Альбом для рисования Сладкие грезы 18 листов ППГ/А3 Альбомы для рисования',
#  'Палаццо Картон цветной Натюрморт 10 листов 10 цветов Картон канцелярский',
#  'Бриз Бумага цветная 16 листов Бумага цветная для творчества',
#  'Апплика Альбом для рисования Веселые животные 20 листов Альбомы для рисования',
#  'Kroyter Альбом для рисования пастелью цвет зеленый 10 листов Альбомы для рисования',
#  'ArtSpace Папка для черчения 10 листов А4 Папки для черчения',
#  'ArtSpace Папка для черчения формат А3 20 листов Папки для черчения',
#  'ArtSpace Папка для черчения 20 листов А4 Папки для черчения',
#  'Kroyter Альбом для рисования пастелью цвет черный 10 листов Альбомы для рисования',
#  'Канц-Эксмо Альбом для рисования Цветочные силуэты 40 листов Альбомы для рисования',
#  'Trolls Картон цветной мелованный 8 листов 8 цветов Картон канцелярский',
#  'ArtSpace Папка для черчения 10 листов с вертикальной рамкой А4 Папки для черчения',
#  'Фиксики Альбом для рисования 40 листов Альбомы для рисования',
#  'Albion Цветная бумага 16 листов 8 цветов Бумага цветная для творчества',
#  'Апплика Цветная бумага Сказочный город 14 листов 7 цветов Бумага цветная для творчества',
#  'Veld-co Цветная бумага самоклеящаяся 8 листов 8 цветов Самоклеящаяся бумага',
#  'Апплика Альбом для рисования Цветы скрапбукинг 20 листов Альбомы для рисования',
#  'Апплика Белый картон 8 листов Картон канцелярский',
#  'Фабрика Фантазий Цветная бумага глиттерная 5 листов Бумага цветная для творчества',
#  ...]

# %% [markdown]
# #### Rank BM25

# %%
from string import punctuation

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
import pymorphy2
import re
import numpy as np
import json
from rank_bm25 import BM25Okapi
from tqdm import tqdm
from typing import List


class BM25Model:
    def __init__(self, max_k=100, prefit=True):
        self.morph = pymorphy2.MorphAnalyzer()
        self.bm25 = None
        self.max_k = max_k
        if prefit:
            self.tokenized_corpus = np.load('tokenized_texts.npy', allow_pickle=True).tolist()
        else:
            self.tokenized_corpus = None

        
    def clear_text(self, text: str):
        text = re.sub('[",*+!:;<=>?@]^_`{|}~]', '', text)
        text = re.sub('\s\d+\s', '', text)
        return text
        
    def lemmatize(self, text):
        words = text.split() # разбиваем текст на слова
        res = list()
        for word in words:
            p = self.morph.parse(word)[0]
            nf = p.normal_form
            if nf not in res:
                res.append(nf)

        return list(res)
    
    def fit(self, corpus: List[str] = []):
        if self.tokenized_corpus is None:
            self.tokenized_corpus = [self.lemmatize(self.clear_text(sent)) for sent in tqdm(corpus)]
        self.bm25 = BM25Okapi(self.tokenized_corpus)
        
    def predict(self, query: str, top_k=None):
        '''Return top_k relevant indexes and their scores'''
        
        if self.bm25 is None:
            raise Exception("Fit model at first!")
            
        tokenized_query = self.lemmatize(self.clear_text(query))
        doc_scores = self.bm25.get_scores(tokenized_query)
        
        if top_k is None:
            n_positive = np.sum(np.array(doc_scores) > 0)
            top_k = np.max([n_positive, self.max_k])
            
        ind = np.argsort(doc_scores)[top_k:][::-1]
        scores = sorted(doc_scores, reverse=True)[:top_k]
        return ind, scores

# %%
bm = BM25Model(prefit=False)

# %%
bm.fit()

# %%
query = "клей универсальный"

# %%
ids, scores = bm.predict(query)

# %%
idx.shape
# Out:
# (350910,)

# %%
df.iloc[ids].head()
# Out:
#           ID СТЕ                         Название СТЕ Категория  \
# 54966   17110611                   Универсальный клей      Клеи
# 169923  24012130                   Клей универсальный      Клеи
# 35565    1355379         Универсальный акриловый клей      Клеи
# 6532     1207490  Клей универсальный "Секунда", 30 мл      Клеи
# 219289  34189970          Бустилат Клей универсальный      Клеи
#
#               Код КПГЗ                                     Характеристики  \
# 54966   01.11.03.07.99  [{"Name":"Вид лакокрасочного материала","Id":-...
# 169923  01.11.03.07.99  [{"Name":"Упаковка","Id":-200564180,"Value":"т...
# 35565   01.11.03.07.99  [{"Name":"Вид продукции","Id":322353980,"Value...
# 6532    01.11.03.07.99  [{"Name":"Тип","Id":286016240,"Value":"клей"},...
# 219289  01.11.03.07.99  [{"Name":"Бренд","Id":340299851,"Value":"Лакра...
#
#                                                 feat_text  \
# 54966   материал, водно-дисперсионный клей, клей, това...
# 169923  18 мес, материал, клей, туба, товары, желтый, ...
# 35565   акриловый латекс, материал, клей, товары, лако...
# 6532       универсальный, 44.00000 г, клей, 30 см[3*];^мл
# 219289  водная полимерная дисперсия, материал, лакра, ...
#
#                                                      text  cat_count  \
# 54966   универсальный клей [SEP] [{"Name":"Вид лакокра...        921
# 169923  клей универсальный [SEP] [{"Name":"Упаковка","...        921
# 35565   универсальный акриловый клей [SEP] [{"Name":"В...        921
# 6532    клей универсальный "секунда", 30 мл [SEP] [{"N...        921
# 219289  бустилат клей универсальный [SEP] [{"Name":"Бр...        921
#
#                                           text25
# 54966                    универсальный клей клеи
# 169923                   клей универсальный клеи
# 35565          универсальный акриловый клей клеи
# 6532    клей универсальный "секунда", 30 мл клеи
# 219289          бустилат клей универсальный клеи

# %%
df["Название СТЕ"].str.lower().str.strip().str.split().to_list()
# Out:
# [['мяч', 'футбольный', 'mikasa', 'regateador5-g'],
#  ['мяч', 'волейбольный', 'gala', 'pro-line', '10', 'fivb'],
#  ['мяч', 'волейбольный', 'mikasa', 'mva380k-obl'],
#  ['мяч', 'волейбольный', 'wilson', 'super', 'soft', 'play'],
#  ['gutrend',
#   'комплект',
#   'расходных',
#   'материалов',
#   'для',
#   'fun',
#   '110',
#   'pet'],
#  ['neolux', 'fsm-05', 'набор', 'фильтров', 'для', 'пылесоса', 'samsung'],
#  ['jura',
#   '62536',
#   'жидкость',
#   'для',
#   'чистки',
#   'автокаппучинатора,',
#   '1',
#   'л'],
#  ['karcher', 'ad', '3.200', '1.629-662.0', 'промышленный', 'пылесос'],
#  ['vitek', 'vt-1886(b)', 'пылесос'],
#  ['philips',
#   'fc8471/01',
#   'powerpro',
#   'compact',
#   'безмешковый',
#   'компактный',
#   'пылесос'],
#  ['philips', 'fc9170/02', 'пылесос'],
#  ['midea', 'vcb33a1', 'пылесос'],
#  ['scarlett', 'sc-vc80b07,', 'red', 'пылесос'],
#  ['samsung', 'sc-20m257awr', 'пылесос'],
#  ['samsung', 'sc-885hh3p', 'пылесос'],
#  ['polaris', 'pvc', '1730сr,', 'red', 'пылесос'],
#  ['samsung', 'vcjg24lv', 'пылесос'],
#  ['samsung', 'sc-4326', 'пылесос'],
#  ['samsung', 'vc18m21d0vg,', 'black', 'пылесос'],
#  ['lg', 'vk76w02hy', 'пылесос'],
#  ['thomas', '785037', 'multi', 'cyclone', 'pro', '14,', 'black', 'пылесос'],
#  ['polaris', 'pvc', '1820g', 'пылесос'],
#  ['samsung', 'sc-18m2110sb', 'пылесос'],
#  ['philips',
#   'fc9352/01',
#   'powerpro',
#   'compact',
#   'безмешковый',
#   'компактный',
#   'пылесос'],
#  ['samsung', 'sc-18m3160vg', 'пылесос'],
#  ['scarlett', 'sc-vc80c03,', 'sky', 'blue', 'пылесос'],
#  ['samsung', 'sc-18m31a0hp', 'пылесос'],
#  ['karcher', 'se', '4002', '1.081-140.0', 'моющий', 'пылесос'],
#  ['thomas', '788565', 'twin', 'xt', 'пылесос'],
#  ['bosch', 'bch6ath18', 'пылесос'],
#  ['нитевдеватель', '"prym"', 'для', 'вышивки'],
#  ['иглы', 'для', 'швейных', 'машин', '"арт",№', '80,', 'уп.10шт,', '162194'],
#  ['иглы',
#   'для',
#   'бытовых',
#   'швейных',
#   'машин',
#   'иглы',
#   'арти',
#   '"0220-01",',
#   'для',
#   'джинсы,',
#   '№90,',
#   '5',
#   'шт'],
#  ['иглы',
#   'для',
#   'промышленных',
#   'швейных',
#   'машин',
#   '"organ",',
#   'dcx27/90,',
#   '10',
#   'шт'],
#  ['иглы',
#   'для',
#   'швейных',
#   'машин',
#   '"иглы',
#   'арти",',
#   'универсальные,',
#   '№80,',
#   '5',
#   'шт'],
#  ['иглы',
#   'для',
#   'швейных',
#   'машин',
#   '"иглы',
#   'арти",',
#   'универсальные,',
#   '№90,',
#   '5',
#   'шт'],
#  ['иглы',
#   'для',
#   'промышленных',
#   'швейных',
#   'машин',
#   'иглы',
#   'арти',
#   '"0277-02",',
#   '№80,',
#   '10',
#   'шт'],
#  ['иглы',
#   'для',
#   'швейных',
#   'машин',
#   '"иглы',
#   'арти",',
#   'универсальные,',
#   '№100,',
#   '5',
#   'шт'],
#  ['иглы',
#   'для',
#   'швейных',
#   'машин',
#   '"иглы',
#   'арти",',
#   'для',
#   'кожи,',
#   '№100,',
#   '5',
#   'шт'],
#  ['иглы',
#   'для',
#   'швейных',
#   'машин',
#   '"иглы',
#   'арти",',
#   'для',
#   'трикотажа,',
#   '№80,',
#   '5',
#   'шт'],
#  ['иглы',
#   'для',
#   'бытовых',
#   'швейных',
#   'машин',
#   'organ',
#   '"blue',
#   'tip',
#   'janome",',
#   '№75,',
#   '5',
#   'шт.162250'],
#  ['иглы',
#   'для',
#   'швейных',
#   'машин',
#   '"иглы',
#   'арти",',
#   'для',
#   'трикотажа,',
#   '№90,',
#   '5',
#   'шт'],
#  ['набор',
#   'универсальных',
#   'игл',
#   'для',
#   'швейных',
#   'машин',
#   '"organ",',
#   '№100,',
#   '5',
#   'шт'],
#  ['иглы',
#   'для',
#   'швейных',
#   'машин',
#   '"organ",',
#   'универсальные,',
#   '№',
#   '80,',
#   '10',
#   'шт'],
#  ['иглы',
#   'для',
#   'промышленных',
#   'швейных',
#   'машин',
#   '"organ",',
#   'dbx1/80,',
#   '10',
#   'шт'],
#  ['иглы',
#   'для',
#   'бытовых',
#   'швейных',
#   'машин',
#   'иглы',
#   'арти',
#   '"0220-06",',
#   '№',
#   '90,',
#   'стрейч',
#   ',',
#   '5',
#   'шт'],
#  ['набор', 'универсальных', 'игл', '"schmetz",', '№100,', '10', 'шт'],
#  ['набор', 'универсальных', 'игл', '"schmetz",', '№100,', '5', 'шт'],
#  ['иглы',
#   'для',
#   'бытовых',
#   'швейных',
#   'машин',
#   '"schmetz",',
#   'универсальные,',
#   '№120,',
#   '5',
#   'шт'],
#  ['иглы',
#   'для',
#   'бытовых',
#   'швейных',
#   'машин',
#   '"schmetz",',
#   'универсальные,',
#   'легковдеваемые,',
#   '№80,',
#   '5',
#   'шт'],
#  ['набор', 'универсальных', 'игл', '"schmetz",', '№80,', '10', 'шт'],
#  ['набор', 'универсальных', 'игл', '"schmetz",', '№90,', '5', 'шт'],
#  ['иглы',
#   'для',
#   'бытовых',
#   'швейных',
#   'машин',
#   '"schmetz",',
#   'универсальные,',
#   '№70,80,',
#   '90,',
#   '5',
#   'шт'],
#  ['иглы',
#   'для',
#   'бытовых',
#   'швейных',
#   'машин',
#   '"schmetz",',
#   'универсальные,',
#   '№80,',
#   '90,',
#   '100,',
#   '5',
#   'шт'],
#  ['нитковдеватель', '"hemline",', '2', 'шт'],
#  ['jaguar', '055d', 'оверлок'],
#  ['janome', 'juno', '5025s', 'швейная', 'машина'],
#  ['brother', 'nv950,', 'white', 'швейно-вышивальная', 'машина'],
#  ['janome', 'dc', '50', 'швейная', 'машина'],
#  ['janome', '419s', 'швейная', 'машина'],
#  ['janome', 'my', 'excel', '1221', 'швейная', 'машина'],
#  ['janome', 'se', '522', 'швейная', 'машина'],
#  ['janome', 'jem', 'швейная', 'машина'],
#  ['janome', 'dc4030,', 'white', 'швейная', 'машина'],
#  ['brother', 'classic', '40', 'швейная', 'машина'],
#  ['janome', '2020', 'швейная', 'машина'],
#  ['janome', '210d', 'оверлок'],
#  ['janome', 'cover', 'pro', '2', 'распошивальная', 'машина'],
#  ['juki', 'mo', '654', 'd', 'оверлок'],
#  ['brother', '3034d', 'оверлок'],
#  ['janome', 'ms', '100', 'швейная', 'машина'],
#  ['comfort', '110', '/140', 'оверлок', '2/3/4-х', 'ниточный'],
#  ['brother', 'm14', 'швейная', 'машина'],
#  ['singer', 'heavy', 'duty', '4423', 'швейная', 'машина'],
#  ['brother', 'lx500', 'швейная', 'машина'],
#  ['janome', 'т-34', 'оверлок'],
#  ['singer', 'confidence', '7640', 'q', 'швейная', 'машина'],
#  ['philips', 'gc1026/30', 'утюг'],
#  ['maxwell', 'mw-3052', '(vt)', 'утюг'],
#  ['philips', 'gc1436/20,', 'blue', 'утюг'],
#  ['philips', 'perfectcare', 'azur', 'gc4922/80', 'утюг', 'с', 'optimaltemp'],
#  ['unit', 'usi-280,', 'blue', 'утюг'],
#  ['scarlett', 'sc-si30k22,', 'blue', 'утюг'],
#  ['mie', 'stiro', '1200', 'парогенератор'],
#  ['maxwell', 'mw-3042(vt)', 'утюг'],
#  ['makita', 'hr2600', 'перфоратор'],
#  ['вихрь', 'ду-1100', 'дрель', 'ударная'],
#  ['makita', 'hp2071', 'дрель', 'ударная'],
#  ['makita', 'hr2460'],
#  ['makita', '6408,', 'дрель'],
#  ['перфоратор', 'makita', 'hr2470ft'],
#  ['дрель-шуруповерт', 'вихрь', 'да-14,4-2,', 'аккумуляторная'],
#  ['makita', 'hr4511c', 'перфоратор', 'sds', 'max'],
#  ['перфоратор', 'makita', 'hr2470'],
#  ['отбойный', 'молоток', 'makita', 'hm1203c'],
#  ['перфоратор', 'makita', 'hr5211с'],
#  ['ударный', 'шуруповерт', 'makita', 'td0101'],
#  ['дрель', 'ударная', 'makita', 'hp2070'],
#  ['makita', 'hr4501c', 'перфоратор'],
#  ['bosch', 'pbh', '2100', 're', '(06033a9320)', 'перфоратор'],
#  ['молоток', 'отбойный', 'makita', 'hm', '0870c'],
#  ['дрель', 'безударная', 'makita', '6413'],
#  ['makita', 'hr5001c', 'перфоратор'],
#  ['makita', 'fs6300', 'шуруповерт'],
#  ['дрель-шуруповерт', 'аккумуляторная', 'fit', 'cd-14lc'],
#  ['дрель', 'ударная', 'makita', 'hp1630'],
#  ['makita', 'hr5201c', 'перфоратор'],
#  ['hitachi', 'um12vst', 'миксер'],
#  ['ударная', 'дрель', 'bosch', 'gsb', '13', 're'],
#  ['перфоратор', 'bosch', 'gbh', '2-26', 'dre'],
#  ['дрель', 'dewalt', 'dwd112s'],
#  ['makita', 'hr3200c', 'перфоратор', 'sds', 'plus'],
#  ['перфоратор', 'bosch', 'gbh', '2-26', 'dfr'],
#  ['шуруповерт', 'bosch', 'psr', '1440', 'li-2', '(06039a3021)'],
#  ['ударная', 'дрель', 'bosch', 'gsb', '16', 're'],
#  ['дрель', 'ударная', 'makita', 'hp1640'],
#  ['дрель', 'ударная', 'black&decker', 'kr604cres'],
#  ['ударная', 'дрель', 'bosch', 'gsb', '1600', 're'],
#  ['отвертка', 'аккумуляторная', 'bort', 'bas-48n-lt'],
#  ['дрель', 'аккумуляторная', 'makita', 'ddf453rfe'],
#  ['перфоратор', 'вихрь', 'п-800к-в'],
#  ['hitachi', 'ds18dvf3-ta', 'шуруповерт'],
#  ['makita', 'hr2300', 'перфоратор', 'sds', 'plus'],
#  ['миксер', 'строительный', 'hammer', 'flex', 'mxr1400a'],
#  ['перфоратор', 'вихрь', 'п-900к'],
#  ['makita', 'dp4001', 'дрель'],
#  ['аккумуляторный', 'шуруповерт', 'bosch', 'ixo', 'v', 'medium'],
#  ['makita', 'dp4003', 'дрель'],
#  ['дрель', 'ударная', 'интерскол', 'ду-16/1000эр'],
#  ['makita', 'dp4010', 'дрель'],
#  ['дрель', 'ударная', 'интерскол', 'ду-13/780эр'],
#  ['makita', 'dp4011', 'дрель'],
#  ['интерскол', 'ду-13/810эр'],
#  ['hyundai', 'h', '800', 'expert', 'перфоратор'],
#  ['дрель-шуруповерт', 'makita', 'df030dwe,', 'аккумуляторная'],
#  ['дрель', 'ударная', 'зубр', 'зду-780', 'эркм2'],
#  ['интерскол', 'км-60/1000э'],
#  ['makita', 'fs4000', 'шуруповерт'],
#  ['дрель', 'ударная', 'ду-850', '(ду-750)', 'вихрь'],
#  ['дрель-шуруповерт', 'defort', '"dcd-12n-7-b",', 'аккумуляторная'],
#  ['дрель', 'ударная', 'зубр', 'зду-850', 'эрмм2'],
#  ['дрель-шуруповерт', 'зубр', 'зсш-300-2,', 'сетевая'],
#  ['дрель-шуруповерт', 'аккумуляторная', 'ставр', '"да-12"'],
#  ['дрель-шуруповерт', 'аккумуляторная', 'bosch', '"psr', '1440', 'li-2"'],
#  ['дрель-шуруповерт', 'аккумуляторная', 'bort', '"bab-10,8nx2li-fdk"'],
#  ['шуруповерт', 'redverg', '"rd-sd14l/2",', 'аккумуляторный'],
#  ['миксер', 'hammer', '"flex', 'mxr1400"'],
#  ['дрель-миксер', 'bpm-1400x2'],
#  ['дрель-шуруповерт', 'аккумуляторная', 'кратон', '"cd-18-k"'],
#  ['дрель', 'ударная', 'зубр', '"мастер",', '810', 'вт'],
#  ['дрель-шуруповерт', 'вихрь', '"да-12-1",', 'аккумуляторная'],
#  ['дрель-шуруповерт', 'вихрь', '"да-12л-2к",', 'аккумуляторная'],
#  ['дрель-шуруповерт', 'вихрь', '"да-14,4л-2к",', 'аккумуляторная'],
#  ['дрель-шуруповерт', '"калибр",', 'аккумуляторная.', 'да-12/2+н550'],
#  ['дрель-шуруповерт', 'вихрь', '"да-18л-2к",', 'аккумуляторная'],
#  ['дрель-шуруповерт',
#   'аккумуляторная',
#   'metabo',
#   '"bs',
#   '18',
#   'ltx',
#   'impuls"'],
#  ['дрель-шуруповерт', 'аккумуляторная', 'bosch', '"gsr', '120-li"'],
#  ['шуруповерт',
#   'аккумуляторный',
#   'metabo',
#   '"powermaxx',
#   'bs',
#   'quick',
#   'basic"'],
#  ['дрель-шуруповерт', 'аккумуляторная', 'metabo', '"bs', '18"'],
#  ['дрель-шуруповерт',
#   'аккумуляторная',
#   'bosch',
#   '"gsr',
#   '12v-15',
#   'fc".',
#   '06019f6001'],
#  ['миксер', 'строительный', '"stanley".', 'sdr1400'],
#  ['дрель-шуруповерт', '"stanley"', 'аккумуляторная,', 'ударная.', 'sch201d2k'],
#  ['дрель', 'ударная', 'bosch', '"easyimpact', '550"'],
#  ['перфоратор', 'bosch', '"gbh', '2-28', 'new".', '0611267500'],
#  ['дрель-шуруповерт', 'аккумуляторная', '"dewalt".', 'dcd710c2'],
#  ['дрель-шуруповерт', 'аккумуляторная', '"makita".', 'df331dwme'],
#  ['дрель-шуруповерт',
#   'аккумуляторная',
#   'интерскол',
#   '"домашний',
#   'мастер".',
#   'да-12эр-01'],
#  ['шуруповерт', 'аккумуляторный', 'dewalt', 'dcd776s2'],
#  ['дрель-шуруповерт', 'аккумуляторная', '"dewalt",', 'ударная.', 'dcd737p2'],
#  ['дрель', 'ударная', 'bosch', '"universalimpact', '700".', '0603131020'],
#  ['насадка-миксер', 'строительная', 'vorel', '"турбо",', 'диаметр', '8', 'см'],
#  ['дрель-шуруповерт', 'аккумуляторная', '"dewalt".', 'dcd710d2'],
#  ['шуруповерт', 'аккумуляторный', '"dewalt".', 'dcd771s2'],
#  ['миксер', 'для', 'краски', '"vorel",', '8,5', 'x', '40', 'см'],
#  ['аккумуляторная', 'ударная', 'дрель-шуруповерт', 'dewalt', 'dcd796d2'],
#  ['шуруповерт', 'аккумуляторный', 'dewalt', '"dcd791d2"'],
#  ['миксер', 'для', 'вязких', 'строительных', 'смесей', 'и', 'клея', '"vorel"'],
#  ['шуруповерт', 'аккумуляторный', 'metabo', '"bs', '18".', '602207500'],
#  ['дрель-шуруповерт',
#   'аккумуляторная',
#   'bosch',
#   '"gsr',
#   '180-li",',
#   '2',
#   'аккумулятора'],
#  ['миксер', 'оцинкованный', 'vorel', '"турбо",', 'c-110'],
#  ['дрель', 'ударная', 'metabo', '"sbe', '650".', '600671510'],
#  ['аккумуляторный', 'винтоверт', 'metabo', '"powermaxx', 'bs', 'basic"'],
#  ['дрель', 'ударная', '"dewalt".', 'dwd024s'],
#  ['шуруповерт', 'аккумуляторный', 'metabo', '"bs', '14.4"'],
#  ['дрель', 'аккумуляторная', 'ударная', 'bosch', '"easyimpact', '12"'],
#  ['перфоратор', 'dewalt', '"sds', 'plus".', 'd25134k'],
#  ['перфоратор', 'metabo', '"khe', '2660', 'sds+".', '600663500'],
#  ['аккумуляторная', 'дрель', 'hammer', 'flex', 'acd120gli'],
#  ['перфоратор', 'metabo', '"khe', '2860', 'sds+".', '600878510'],
#  ['аккумуляторный',
#   'перфоратор',
#   'bosch',
#   'gbh',
#   '180-li,',
#   '2',
#   'акб.',
#   '0611911023'],
#  ['дрель-шуруповерт', 'аккумуляторная', 'bort', '"bab-18ux2li-fdk"'],
#  ['вибрационная',
#   'шлифмашина',
#   'bosch',
#   'pss',
#   '250',
#   'ae',
#   'pss',
#   '250',
#   'ae'],
#  ['шлифмашина', 'угловая', 'makita', '9069sf'],
#  ['шлифмашина', 'угловая', 'makita', '9069', 'f'],
#  ['шлифмашина', 'угловая', 'makita', 'ga9020'],
#  ['шлифмашина', 'угловая', 'makita', '9069'],
#  ['шлифмашина', 'вибрационная', 'makita', 'bo3710'],
#  ['шлифмашина', 'эксцентриковая', 'bo', '5030'],
#  ['шлифмашина', 'эксцентриковая', 'bo5031'],
#  ['шлифмашина', 'эксцентриковая', 'dewalt', 'd26410'],
#  ['шлифмашина', 'угловая', 'интерскол', 'ушм-150/1300'],
#  ['шлифмашина', 'угловая', 'makita', 'ga4530'],
#  ['шлифмашина', 'угловая', 'интерскол', 'ушм-180/1800м'],
#  ['шлифмашина', 'угловая', 'makita', '9558hnk'],
#  ['шлифмашина', 'угловая', 'makita', 'ga5030'],
#  ['шлифмашина', 'угловая', 'makita', 'ga9020sf'],
#  ['шлифмашина', 'вибрационная', 'makita', 'bo3711'],
#  ['точильный', 'станок', 'вихрь', 'тс-200'],
#  ['точильный', 'станок', 'вихрь', 'тс-400'],
#  ['угловая', 'шлифмашина', 'makita', '9562cvh'],
#  ['ленточная', 'шлифмашина', 'makita', '9910k'],
#  ['шлифмашина', 'угловая', 'makita', '9558hn'],
#  ['угловая', 'шлифмашина', 'makita', '9565cvk'],
#  ['угловая', 'шлифмашина', 'makita', 'ga7010c'],
#  ['станок', 'для', 'заточки', 'цепей', 'вихрь', 'сзц-200'],
#  ['шлифмашина', 'угловая', 'вихрь', 'ушм-125/900'],
#  ['шлифовальная', 'машина', 'black&decker', 'ka88'],
#  ['шлифмашина', 'эксцентриковая', 'bo5030k'],
#  ['угловая', 'шлифмашина', 'bosch', 'gws', '20-230', 'h', 'professional'],
#  ['шлифмашина', 'ленточная', 'makita', '9910'],
#  ['шлифмашина', 'вибрационная', 'makita', 'во4565'],
#  ['шлифмашина', 'ленточная', '"зубр"'],
#  ['угловая', 'шлифмашина', 'bosch', 'gws', '22-230', 'jh'],
#  ['многофункциональный', 'инструмент', '"dremel', '4000".', 'f0134000lr'],
#  ['многофункциональный', 'инструмент', 'dremel', '"4000-', '4/65"'],
#  ['реноватор', 'bosch', '"pmf', '220', 'ce"'],
#  ['реноватор', 'bosch', '"pmf', '250', 'ces"'],
#  ['шлифмашина', 'угловая', 'bosch', '"pws', '700-125".', '06033a2023'],
#  ['инструмент', 'многофункциональный', 'hammer', 'premium', 'lzk500s'],
#  ['машина', 'шлифовальная', 'metabo', '"w', '850-125",', 'угловая'],
#  ['машина', 'углошлифовальная', '(ушм)', 'patriot', 'ag122'],
#  ['машина', 'углошлифовальная', '(ушм)', 'patriot', 'ag230'],
#  ['шлифмашина', 'угловая', 'metabo', '"w', '2200-230"'],
#  ['многофункциональный',
#   'инструмент',
#   'dremel',
#   '"8220-5/65',
#   'platinum",',
#   'аккумуляторный,',
#   '12v.',
#   'f0138220jn'],
#  ['углошлифовальная', 'машина', 'dewalt', 'dwe4215'],
#  ['шлифмашина', 'угловая', 'metabo', '"w', '2400-230"'],
#  ['многофункциональный', 'инструмент', 'dremel', '"4300-3/45".', 'f0134300jd'],
#  ['пила', 'монтажная', 'metabo', '"cs', '23-355"'],
#  ['шлифмашина',
#   'угловая',
#   'hitachi',
#   '"g13sr4"',
#   'с',
#   'алмазным',
#   'диском',
#   'carat'],
#  ['шлифмашина', 'эксцентриковая', 'metabo', '"sxe', '3125"'],
#  ['инструмент', 'многофункциональный', 'hammer', 'flex', 'lzk200'],
#  ['углошлифовальная',
#   'машина',
#   '(болгарка)',
#   'зубр',
#   'ушм-125-800',
#   'м3,',
#   '125',
#   'мм,',
#   '800',
#   'вт'],
#  ['углошлифовальная', 'машина', 'dewalt', 'dwe4579'],
#  ['шлифмашина', 'вибрационная', 'metabo', '"fms', '200', 'intec"'],
#  ['точило', 'hammer', 'flex', 'tsl200b'],
#  ['машина', 'углошлифовальная', '"dewalt".', 'dwe4051'],
#  ['станок', 'точильный', 'двойной', 'зубр', '"мастер",', '150', 'вт'],
#  ['станок', 'точильный', 'двойной', 'зубр', 'зтшм-200-450,', '450', 'вт'],
#  ['электролобзик', 'makita', '4350ct'],
#  ['электролобзик', 'makita', '4327'],
#  ['электролобзик', 'makita', '4329'],
#  ['пила', 'дисковая', '5903r'],
#  ['пила', 'дисковая', 'bosch', 'pks', '55', '(0603500020)'],
#  ['электролобзик', 'bosch', 'pst', '700', 'e'],
#  ['электроножницы', 'по', 'металлу', 'makita', 'jn1601'],
#  ['электролобзик', 'bosch', 'pst', '900', 'pel', '(06033a0220)'],
#  ['электролобзик', 'makita', '4326'],
#  ['пила', 'дисковая', 'sp', '6000'],
#  ['электролобзик', 'bosch', 'pst', '650', '(06033a0720)'],
#  ['дисковая', 'пила', 'вихрь', 'дп-185/1300'],
#  ['электролобзик', 'интерскол', 'мп-100/700э'],
#  ['пила', 'дисковая', 'интерскол', 'дп-235/2000м'],
#  ['пила', 'дисковая', 'интерскол', 'дп-190/1600м'],
#  ['пила', 'дисковая', 'интерскол', 'дп-165/1200'],
#  ['пила', 'дисковая', 'с6ss'],
#  ['пила', 'сабельная', 'bosch', 'psa', '700', 'e', '(06033a7020)'],
#  ['makita', '4329k', 'электрололбзик'],
#  ['дисковая', 'пила', 'bosch', 'pks', '66', 'a', '(0603502022)'],
#  ['пила', 'дисковая', 'интерскол', 'дп-140/800'],
#  ['пила', 'торцовочная', 'stl800', 'пила', 'торцовочная'],
#  ['электролобзик', 'makita', 'jv0600k'],
#  ['пила', 'торцовочная', 'ls0714'],
#  ['электролобзик', 'интерскол', 'мп-65/550э'],
#  ['циркулярная', 'двухдисковая', 'пила', 'hammer', '66398'],
#  ['пила', 'универсальная', 'black&decker', '"scorpion"'],
#  ['пила', 'монтажная', 'makita', '2414nb'],
#  ['пила', 'дисковая', 'makita', '5008mg'],
#  ['пила', 'сабельная', 'makita', 'jr3050t'],
#  ['лобзиковая', 'пила', 'bosch', 'gst', '90', 'e', 'professional'],
#  ['лобзиковая', 'пила', 'bosch', 'gst', '850', 'be', 'professional'],
#  ['ручная', 'циркулярная', 'пила', 'bosch', 'gks', '190', 'professional'],
#  ['электролобзик', 'bosch', 'pst', '750', 'pe', '06033a0520'],
#  ['циркулярная', 'пила', 'bosch', '"pks', '18', 'li",', 'аккумуляторная'],
#  ['пила', 'сабельная', 'bosch', '"gsa', '1300', 'pce".', '060164e200'],
#  ['лобзик', 'электрический', '"dewalt".', 'dw341k'],
#  ['пила', 'торцовочная', '(стусло)', 'hammer', 'flex', 'stl1400/210'],
#  ['лобзик', 'электрический', 'ставр', '"лэ-65/600"'],
#  ['лобзик', 'электрический', '"dewalt".', 'dw349'],
#  ['пила', 'дисковая', '"dewalt",', 'электрическая.', 'dwe550'],
#  ['электропила', 'partner', 'p820t'],
#  ['пила', 'дисковая', 'dewalt', 'dwe575k'],
#  ['плиткорез', 'dewalt', 'dwc410'],
#  ['плиткорез', 'электрический', '"stanley".', 'stsp125'],
#  ['пила',
#   'аккумуляторная',
#   'мини-цепная',
#   'bosch',
#   '"easycut',
#   '12".',
#   '06033c9020'],
#  ['лобзик', 'электрический', 'makita', '"4329x1"'],
#  ['электролобзик', 'bosch', '"gst', '8000', 'e".', '060158h001'],
#  ['пила', 'монтажная', '"dewalt",', 'с', 'абразивным', 'диском.', 'd28715'],
#  ['пила', 'торцевая', 'ставр', '"пт-210/1400м"'],
#  ['пила', 'дисковая', 'metabo', '"ks', '55', 'fs"'],
#  ['пила', 'торцовочная', 'metabo', '"kgs', '216', 'm"'],
#  ['лобзик', 'электрический', 'metabo', '"steb', '65', 'quick".', '601030000'],
#  ['лобзик', 'электрический', 'metabo', '"steb', '70', 'quick".', '601040500'],
#  ['лобзик', 'электрический', 'metabo', '"steb', '80', 'quick"'],
#  ['лобзик', 'электрический', 'metabo', '"ste', '100', 'quick".', '601100000'],
#  ['зубр', 'зр-1300-110', 'электрический', 'рубанок,', '1300вт'],
#  ['электрорубанок', 'интерскол', 'р-110/1100м'],
#  ['электрорубанок', 'makita', 'kp0800'],
#  ['рубанок', 'электрический', 'makita', '1911b'],
#  ['рубанок', 'электрический', 'bort', '"bfb-1300-t"'],
#  ['электрорубанок', 'makita', 'kp0810'],
#  ['рубанок', 'электрический', 'dwt', '"hb03-82"'],
#  ['рубанок', 'bosch', '"gho', '6500".', '0601596000'],
#  ['рубанок', 'bosch', '"gho', '26-82', 'd".', '06015a4301'],
#  ['фрезер', 'электрический', 'makita', 'rp2300fc'],
#  ['фрезер', 'электрический', 'makita', '3612c'],
#  ['фрезер', 'bosch', '"gmf', '1600', 'ce', 'l-boxx"'],
#  ['фрезер', 'bosch', 'pof', '1400', 'ace', '(060326c820)'],
#  ['бумажные', 'фильтр-мешки', 'karcher', '5', 'шт.', '6.904-322.0'],
#  ['venta', 'гигиеническая', 'добавка'],
#  ['philips', 'saeco', 'ca6700/10', 'средство', 'от', 'накипи'],
#  ['jura', '62715', 'таблетка', 'для', 'чистки', 'гидросистемы,', '6', 'шт'],
#  ['jura', '63801', 'жидкость', 'для', 'чистки', 'каппучинатора,', '250', 'мл'],
#  ['karcher', '28630060', 'фильтр', 'для', 'wd', '4/5/6'],
#  ['caso',
#   'vc',
#   '16х23',
#   'пакеты',
#   'для',
#   'вакуумного',
#   'упаковщика,',
#   '50',
#   'шт'],
#  ['karcher', '28631120', 'шланг', 'для', 'пылесоса'],
#  ['karcher', '64149630', 'hepa-фильтр', 'для', 'пылесоса'],
#  ['karcher', '69591300', 'фильтр', 'для', 'se/wd,', '5', 'шт'],
#  ['bestex',
#   'шпулька',
#   'пластиковая',
#   'н/н',
#   '5819,',
#   'для',
#   'вертикальных',
#   'шпульных',
#   'колпачков'],
#  ['набор',
#   'шпулек',
#   '"bestex",',
#   'для',
#   'швейный',
#   'машин',
#   '"singer",',
#   '10',
#   'шт'],
#  ['brand', '360', 'аппарат', 'для', 'сахарной', 'ваты'],
#  ['bosch', '311813', 'набор', 'средств', 'для', 'кофемашин'],
#  ['filtero', 'eio', '01', 'экстра', 'мешок-пылесборник', '4', 'шт'],
#  ['адаптер', 'kenwood', 'kat002me'],
#  ['panda',
#   'комплект',
#   'расходных',
#   'материалов',
#   'для',
#   'x500',
#   'pet',
#   'series'],
#  ['topperr', 'fsm', '881', 'hepa-фильтр', 'для', 'пылесосов', 'samsung'],
#  ['лапка',
#   'для',
#   'швейной',
#   'машины',
#   '"aurora",',
#   'для',
#   'косой',
#   'бейки,',
#   'с',
#   'линейкой'],
#  ['topperr', 'nt', '2', 'насадка', 'универсальная', 'для', 'пылесоса'],
#  ['лампочка',
#   'для',
#   'швейных',
#   'машин',
#   '"hemline",',
#   'тип',
#   'b,',
#   'вставляющаяся,',
#   'средняя'],
#  ['electrolux', 'a7531', 'фильтр-картридж', 'для', 'увлажнителя', 'воздуха'],
#  ['шпульки',
#   '"hemline"',
#   'для',
#   'швейных',
#   'машин',
#   'janome/new',
#   'home,',
#   '10',
#   'шт'],
#  ['бумажные',
#   'мешки',
#   'для',
#   'bosch',
#   '"advancedvac',
#   '20",',
#   '5',
#   'шт.',
#   '2609256f33'],
#  ['шпульки',
#   'для',
#   'швейных',
#   'машин',
#   '"hemline",',
#   'стандартные,',
#   '3',
#   'шт'],
#  ['булавки-гвоздики',
#   'декоративные',
#   '"hemline",',
#   'в',
#   'контейнере,',
#   '450',
#   'шт'],
#  ['gastrorag', 'hec-01', 'аппарат', 'для', 'сахарной', 'ваты'],
#  ['набор',
#   'лапок',
#   'для',
#   'швейной',
#   'машины',
#   '"aurora",',
#   '15',
#   'предметов'],
#  ['лапка',
#   'для',
#   'притачивания',
#   'молнии',
#   '"hemline",',
#   'регулируемая,',
#   '3,5',
#   'х',
#   '2',
#   'х',
#   '4,5',
#   'см'],
#  ['topperr',
#   'eo',
#   '4',
#   'фильтр',
#   'для',
#   'пылесосов',
#   'bork,',
#   'cameron',
#   'и',
#   'eio,',
#   '5',
#   'шт'],
#  ['ozone', 'h-09', 'набор', 'универсальных', 'фильтров,', '3', 'шт'],
#  ['пинцет',
#   'для',
#   'оверлоков',
#   'и',
#   'швейных',
#   'машин',
#   '"hemline",',
#   'с',
#   'тонкими',
#   'кончиками,',
#   'длина',
#   '15',
#   'см'],
#  ['filtero',
#   'bsh',
#   '20',
#   'pro',
#   'комплект',
#   'пылесборников',
#   'для',
#   'промышленных',
#   'пылесосов,',
#   '5',
#   'шт'],
#  ['stadler', 'form', 'mia,', 'white', 'ароматизатор', 'воздуха'],
#  ['лапка',
#   'для',
#   'швейной',
#   'машины',
#   '"aurora",',
#   'для',
#   'потайной',
#   'молнии'],
#  ['набор',
#   'мешков',
#   '"metabo",',
#   'для',
#   'пылесосов',
#   'asa25lpc,',
#   'asa30lpc,',
#   '25',
#   'л,',
#   '5',
#   'шт.',
#   '6.30296'],
#  ['шпульки',
#   '"hemline"',
#   'для',
#   'швейных',
#   'машин',
#   'singer',
#   'серии',
#   '"auto',
#   'wind"',
#   '600/700,',
#   '10',
#   'шт'],
#  ['шпульки',
#   '"hemline",',
#   'для',
#   'швейных',
#   'машин',
#   'джаноме/нью',
#   'хоум,',
#   '3',
#   'шт'],
#  ['filtero', 'ftm', '09', 'фильтр', 'для', 'пылесосов'],
#  ['лапка', 'для', 'швейной', 'машины', '"aurora",', 'шагающая,', '7', 'мм'],
#  ['шпульки',
#   '"hemline",',
#   'для',
#   'швейных',
#   'машин',
#   'зингер',
#   'с',
#   'горизонтальным',
#   'челноком,',
#   '3',
#   'шт'],
#  ['filtero',
#   'fp',
#   '120',
#   'pet',
#   'pro',
#   'фильтр',
#   'складчатый',
#   'для',
#   'пылесосов',
#   'bosch,',
#   'makita,',
#   'metabo,',
#   'nilfisk'],
#  ['philips', 'gc2995/30', 'powerlife,', 'white', 'purple', 'утюг'],
#  ['philips', 'gc2998/80', 'powerlife,', 'black', 'dark', 'gray', 'утюг'],
#  ['philips', 'gc4939/00', 'azur', 'advanced,', 'bronze', 'black', 'утюг'],
#  ['mie', 'piccolo', 'ручной', 'отпариватель'],
#  ['philips', 'gc514/40', 'вертикальный', 'отпариватель', 'для', 'одежды'],
#  ['bieffe', 'emilio', 'ra', 'auto', 'пароочиститель'],
#  ['tefal', 'sv6020', 'парогенератор'],
#  ['mie', 'romeo', '2,', 'white', 'гладильный', 'пресс'],
#  ['karcher', 'wv', '50', 'plus', '1.633-117.0', 'стеклоочиститель'],
#  ['соэкс', '2', 'эко-тестер'],
#  ['соэкс', '01м', 'прайм', 'дозиметр'],
#  ['соэкс', 'эковизор', 'f4'],
#  ['braun', 'mq745', 'aperitif', 'блендер'],
#  ['rohaus', 'rs910s', 'стационарный', 'блендер'],
#  ['redmond', 'rhb-cb2931', 'блендер'],
#  ['irit', 'ir-5512,', 'green', 'блендер'],
#  ['scarlett', 'sc-hb42m33,', 'white', 'блендер', 'погружной'],
#  ['kitfort', 'кт-1310', 'блендер'],
#  ['bosch', 'msm2610b,', 'black', 'блендер'],
#  ['irit', 'ir-5512,', 'purple', 'блендер'],
#  ['bosch', 'mfq', '4020', 'миксер'],
#  ['smile', 'ms', '754', 'миксер', 'для', 'молока'],
#  ['galaxy', 'gl', '2206', 'миксер'],
#  ['galaxy', 'gl', '2210', 'миксер'],
#  ['polaris', 'phm', '5009a', 'миксер'],
#  ['bosch', 'mmr15a1', 'измельчитель'],
#  ['russell', 'hobbs', '22281-56', 'aura', 'slice', '&', 'go', 'овощерезка'],
#  ['tefal', 'py6044', 'блинница', "crep'party", 'dual'],
#  ['maxwell', 'mw-1571', 'вафельница'],
#  ['tristar', 'bp-2634,', 'black', 'блинница'],
#  ['redmond', 'rmb-m603', 'мультипекарь'],
#  ['tefal', 'py', '3036', '33', 'блинница'],
#  ['moulinex', 'sw611812', 'сэндвичница'],
#  ['bosch', 'mum', '4855', 'кухонный', 'комбайн'],
#  ['braun', 'fp5150wh', 'кухонный', 'комбайн'],
#  ['vitek', 'vt-1506(bk)', 'кофеварка'],
#  ['redmond', 'rcm-m1507', 'кофеварка'],
#  ['delonghi', 'en', '126', 'nespresso', 'pixie', 'clips', 'кофеварка'],
#  ['tefal', 'cm361e38', 'кофеварка'],
#  ['philips', 'hd8649/51', 'кофемашина'],
#  ['delonghi', 'magnifica', 'ecam', '22.110.sb,', 'кофемашина'],
#  ['delonghi', 'autentica', 'etam', '29.660.sb', 'кофемашина'],
#  ['delonghi', 'magnifica', 'ecam', '22.110.b', 'кофемашина'],
#  ['delonghi', 'etam29.510.sb', 'кофемашина'],
#  ['delonghi', 'dinamica', 'ecam', '350.15.b', 'кофемашина'],
#  ['delonghi',
#   'nespresso',
#   'pixie',
#   'clips',
#   'en',
#   '126',
#   'капсульная',
#   'кофемашина'],
#  ['kitfort', 'кт-1315', 'кофемолка'],
#  ['profi', 'cook', 'pc-kw', '1061', 'кухонные', 'весы'],
#  ['maxwell', 'mw-1451,', 'silver', 'весы', 'кухонные'],
#  ['redmond', 'rs-736', 'полоски', 'весы', 'кухонные'],
#  ['irit', 'ir-7118', 'весы', 'кухонные'],
#  ['scarlett', 'sc-ks57p99,', 'steel', 'весы', 'кухонные'],
#  ['polaris', 'pks', '1046dg', 'cherry', 'кухонные', 'весы'],
#  ['starwind', 'ssk3354,', 'brown', 'red', 'blue', 'весы', 'кухонные'],
#  ['lumme', 'lu-1340', '"ягодный', 'микс"', 'весы', 'кухонные'],
#  ['samsung', 'me-83xr', 'свч-печь'],
#  ['samsung', 'me81krw-1', 'свч-печь'],
#  ['samsung', 'me-83krw-2', 'свч-печь'],
#  ['bbk', '20mws-704m/w', 'микроволновая', 'печь'],
#  ['lg', 'mh6044v', 'свч-печь'],
#  ['daewoo', 'kor-5a17,', 'white', 'green', 'свч-печь'],
#  ['bbk', '20mws-713m/w,', 'white', 'свч-печь'],
#  ['samsung', 'mc-28h5013aw', 'свч-печь'],
#  ['redmond', 'rm-2002d', 'свч-печь'],
#  ['gastrorag', 'wd90023slb7', 'свч-печь'],
#  ['samsung', 'ms-23f302tas,', 'steel', 'свч-печь'],
#  ['samsung', 'me83krqw-3', 'свч-печь'],
#  ['sharp', 'r-2000rw,', 'black', 'white', 'микроволновая', 'печь'],
#  ['redmond', 'rmc-m90', 'black', 'мультиварка'],
#  ['redmond', 'rmc-pm400', 'мультиварка'],
#  ['maxwell', 'mw-1906(st)', 'плитка', 'электрическая'],
#  ['smile', 'sep', '9005', 'плитка', 'электрическая'],
#  ['galaxy', 'gl', '3001', 'плитка', 'электрическая'],
#  ['marta', 'lumme', 'lu-3608', 'электроплитка'],
#  ['gemlux', 'gl-ip22e', 'плита', 'настольная', 'индукционная'],
#  ['gastrorag', 'ha-720,', 'silver', 'соковыжималка'],
#  ['tristar', 'cf-1603', 'шоколадный', 'фонтан'],
#  ['tristar', 'yb-2611', 'карамелизатор'],
#  ['status', 'sv', '2000', 'вакуумный', 'упаковщик'],
#  ['philips', 'hd2635/90,', 'black', 'silver', 'тостер'],
#  ['caso', 'inox', '4', 'тостер'],
#  ['gastrorag', 'czg-40-2', 'фритюрница'],
#  ['bosch', 'twk', '1201n', 'электрочайник'],
#  ['bosch', 'twk3a011,', 'электрочайник'],
#  ['bosch', 'twk3a013', 'электрочайник'],
#  ['philips', 'hd9306/02', 'электрический', 'чайник'],
#  ['zimber', 'zm-10838', 'электрический', 'чайник'],
#  ['bosch', 'twk', '7901,', 'silver', 'электрический', 'чайник'],
#  ['redmond',
#   'skykettle',
#   'rk-m171s,',
#   'metallic',
#   'умный',
#   'электрический',
#   'чайник'],
#  ['bosch', 'twk7805,', 'black', 'электрический', 'чайник'],
#  ['maxwell', 'mw-1014(bn)', 'электрический', 'чайник'],
#  ['bosch', 'twk', '7808,', 'gold', 'чайник'],
#  ['energy', 'e-209,', 'beige', 'электрический', 'чайник'],
#  ['energy', 'e-277', 'электрический', 'чайник'],
#  ['first', 'fa-5410-4', 'stell', 'электрочайник'],
#  ['tefal', 'ki270530', 'чайник'],
#  ['tefal', 'ki270930', 'чайник'],
#  ['redmond', 'skykettle', 'm173s-e', 'умный', 'электрический', 'чайник'],
#  ['tefal', 'ki240d30', 'чайник', 'электрический'],
#  ['vitek', 'vt-7020', 'st', 'чайник', 'электрический'],
#  ['boneco', 's250,', 'white', 'увлажнитель', 'воздуха'],
#  ['venta', 'lw', '45,', 'white', 'мойка', 'воздуха'],
#  ['honeywell', 'cl30xc', 'микроклиматическая', 'установка'],
#  ['супер',
#   'плюс',
#   'био',
#   'с',
#   'жк-дисплеем',
#   'очиститель-ионизатор',
#   'воздуха'],
#  ['супер', 'плюс', 'турбо', 'очиститель-ионизатор', 'воздуха'],
#  ['супер', 'плюс', 'био', 'очиститель-ионизатор', 'воздуха'],
#  ['stadler', 'form', 'robert', 'r-001r', 'мойка', 'воздуха'],
#  ['boneco', 'w2055d,', 'black', 'мойка', 'воздуха'],
#  ['boneco', 'w2055dr,', 'royal', 'black', 'мойка', 'воздуха'],
#  ['ballu', 'aw-325,', 'white', 'мойка', 'воздуха'],
#  ['honeywell', 'es800', 'увлажнитель', 'воздуха'],
#  ['delta', 'dl-023h', 'вентилятор'],
#  ['maxwell', 'mw-3547(w)', 'вентилятор', 'настольный'],
#  ['breville', 'p365', 'вентилятор'],
#  ['first', 'fa-5560-2,', 'black', 'вентилятор', 'напольный'],
#  ['бирюса', '50', 'холодильник'],
#  ['gastrorag', 'bch-40b,', 'black', 'холодильник'],
#  ['славда', 'ws-50pet', 'стиральная', 'машина'],
#  ['bomann', 'tsg', '707,', 'silver', 'посудомоечная', 'машина'],
#  ['ricci', 'rrh-2260-wh', 'вытяжка'],
#  ['hotfrost', 'стаканодержатель', 'на', '70', 'стаканчиков,', 'silver'],
#  ['vatten', 'v45se', 'кулер', 'для', 'воды,', 'silver'],
#  ['vatten', 'v45qe', 'кулер', 'для', 'воды,', 'champagne'],
#  ['hotfrost', 'v118', 'кулер', 'для', 'воды'],
#  ['vatten', 'v41', 'we', 'кулер', 'для', 'воды,', 'white'],
#  ['vatten', '№3m,', 'blue', 'механическая', 'помпа', 'для', 'воды'],
#  ['aqua', 'work', '16lw/hln', 'диспенсер', 'для', 'воды'],
#  ['vatten', 'v42', 'ne,', 'black', 'кулер', 'для', 'воды'],
#  ['vatten', '№5,', 'blue', 'механическая', 'помпа', 'для', 'воды'],
#  ['aqua', 'work', '16ld/en,', 'white', 'кулер', 'для', 'воды'],
#  ['aqua', 'work', '0.7ld', 'кулер', 'для', 'воды'],
#  ['aqua', 'work', '1665s', 'кулер', 'для', 'воды'],
#  ['aqua', 'work', '16ld/hln', 'кулер', 'для', 'воды'],
#  ['simfer', 'h60d17b011', 'панель', 'варочная', 'электрическая'],
#  ['venta', 'термогигрометр'],
#  ['scarlett', 'sc-ek27g18,', 'black', 'чайник', 'электрический'],
#  ['scarlett', 'sc-ek21s43,', 'stainless', 'steel', 'электрический', 'чайник'],
#  ['irit', 'ir-1320', 'электрический', 'чайник'],
#  ['gemlux', 'gl-k101ss', 'чайник', 'электрический'],
#  ['gastrorag', 'dk-lx-100', 'кипятильник'],
#  ['gastrorag', 'dk-lx-200', 'кипятильник'],
#  ['gastrorag', 'dk-pu-100', 'кипятильник'],
#  ['gemlux', 'gl-wb-200s', 'электрокипятильник'],
#  ['galaxy', 'gl', '0318,', 'white', 'электрический', 'чайник'],
#  ['kitfort', 'кт-621', 'чайник', 'электрический'],
#  ['kitfort', 'кт-623', 'чайник', 'электрический'],
#  ['rommelsbacher', 'ga', '1700', 'термопот'],
#  ['rommelsbacher', 'ga', '1000', 'термопот'],
#  ['galaxy', 'gl', '0606', 'термопот'],
#  ['galaxy', 'gl', '0607,', 'silver', 'термопот'],
#  ['galaxy', 'gl', '0605', 'термопот'],
#  ['energy', 'tp-617,', 'white', 'термопот'],
#  ['galaxy', 'gl', '0603', 'термопот'],
#  ['energy', 'tp-617', 'термопот'],
#  ['scarlett', 'sc-et10d13,', 'black', 'термопот'],
#  ['tefal', 'gc306012', 'health', 'grill', 'comfort', 'электрогриль'],
#  ['caso', 'bg', '1000,', 'black', 'steel', 'электрогриль'],
#  ['philips', 'bhd001/00', 'фен'],
#  ['remington', 'd5000', 'compact', '1800', 'фен'],
#  ['moser', 'protect,', 'black', 'фен', 'профессиональный'],
#  ['philips', 'hp8238/00,', 'black', 'фен'],
#  ['aeg', 'htd', '5649', 'фен'],
#  ['polaris', 'phd', '2077i,', 'purple', 'фен'],
#  ['vitek', 'vt-2269(bk)', 'фен'],
#  ['dewal', 'ion', 'energy', '03-8800,', 'black', 'фен'],
#  ['scarlett', 'sc-hd70i47', 'фен'],
#  ['valera', 'hotello', 'shaver,', 'white', 'фен'],
#  ['valera', 'premium', '1600', 'super,', 'white', 'фен'],
#  ['dewal', 'profile', '2200,', 'aqua', 'фен'],
#  ['valera', 'hotello,', 'white', 'фен'],
#  ['stadler',
#   'form',
#   'anna',
#   'big',
#   'a-020e,',
#   'white',
#   'керамический',
#   'обогреватель'],
#  ['stadler',
#   'form',
#   'anna',
#   'big',
#   'a-021e,',
#   'black',
#   'керамический',
#   'обогреватель'],
#  ['ресанта', 'омм-7н', '(0,7', 'квт)', 'напольный', 'радиатор'],
#  ['ресанта', 'омпт-9н', '(2', 'квт)', 'напольный', 'радиатор'],
#  ['ресанта', 'омпт-12н', '(2,5', 'квт)', 'напольный', 'радиатор'],
#  ['ресанта', 'ом-7н', '(1,5', 'квт)', 'напольный', 'радиатор'],
#  ['ресанта', 'ок-1000', 'конвектор'],
#  ['neoclima', 'comforte', 'т1.5', 'эвна', 'с2', 'конвектор'],
#  ['electrolux', 'ehda/hpw-1800w', 'сушилка', 'для', 'рук'],
#  ['тепловая', 'пушка', 'ресанта', 'тэп-5000'],
#  ['ballu', '09m/bhh', 'галогеновый', 'обогреватель'],
#  ['supra', 'hss-3001', 'щипцы', 'для', 'завивки', 'волос'],
#  ['ballu', '09brn-boh/cl', 'масляный', 'обогреватель'],
#  ['dewal', 'titaniumt', 'pro', '03-25т', 'плойка', 'для', 'волос'],
#  ['тепловая', 'пушка', 'ресанта', 'тэп-5000к1'],
#  ['electrolux', '5115c/efh,', 'white', 'тепловентилятор'],
#  ['neoclima', 'liten', '9016', 'тепловентилятор'],
#  ['electrolux', 'eoh/m-5209', 'sport', 'line'],
#  ['тепловая', 'пушка', 'ресанта', 'тэп-3000к'],
#  ['dewal', 'titaniumt', 'pro', '03-25а', 'плойка', 'для', 'волос'],
#  ['electrolux', '3209m/eoh', 'масляный', 'обогреватель'],
#  ['shivaki', 'shif-gs70y', 'тепловая', 'газовая', 'пушка'],
#  ['hisense', 'dh-25k4hdl', 'осушитель', 'воздуха'],
#  ['dewal', 'titaniumt', 'pro', '03-33а', 'плойка', 'для', 'волос'],
#  ['ballu', 'comfort', 'boh/cm-07wd', 'масляный', 'радиатор'],
#  ['ballu', 'enzo', 'bec/ezmr-1000', 'обогреватель'],
#  ['zilon', 'ztv-9c', 'тепловая', 'пушка'],
#  ['ballu', 'enzo', 'bec/ezmr-1500', 'обогреватель'],
#  ['ballu', 'enzo', 'bec/ezmr-2000', 'обогреватель'],
#  ['ewt', 'or', '125tls,', 'white', 'масляный', 'радиатор'],
#  ['electrolux', '5115c/efh,', 'black', 'тепловентилятор'],
#  ['ресанта', 'ок-2500', 'конвектор'],
#  ['ресанта', 'тз-5с', 'тепловая', 'завеса'],
#  ['galaxy', 'gl', '4622', 'плойка'],
#  ['moser',
#   'chrom',
#   'style',
#   'pro',
#   'машинка',
#   'для',
#   'стрижки',
#   '(1871-0071)'],
#  ['moser', 'easystyle', '1881-0051', 'машинка', 'для', 'стрижки'],
#  ['polaris', 'pqsh', '0208', 'кварцевый', 'обогреватель'],
#  ['dewal', '03-012', 'машинка', 'для', 'стрижки'],
#  ['алмак', 'ик-5,', 'white', 'инфракрасный', 'обогреватель'],
#  ['moser', 'lipro', 'машинка', 'для', 'стрижки', '(1884-0050)'],
#  ['ballu',
#   'classic',
#   'boh/cl-07',
#   'br',
#   '1500,',
#   'black',
#   'радиатор',
#   'масляный'],
#  ['timberk', 'tec.e0', 'm', '1500', 'конвектор'],
#  ['neoclima', 'nd-10ah', 'осушитель', 'воздуха'],
#  ['hyundai', 'h-hv15-15-ui618', 'конвектор', 'электрический'],
#  ['алмак', 'ик-13,', 'wenge', 'инфракрасный', 'обогреватель'],
#  ['hyundai', 'h-hv16-10-ui620', 'конвектор', 'электрический'],
#  ['hyundai', 'h-hv16-15-ui621', 'конвектор', 'электрический'],
#  ['electrolux', 'prime', 'efh/s-1125', 'тепловентилятор'],
#  ['scarlett', 'sca', 'h', 'ver14', '2000', 'конвектор', 'электрический'],
#  ['electrolux', 'ech/as-2000mr', 'конвектор'],
#  ['electrolux', 'ech/as-2000er', 'конвектор'],
#  ['electrolux', 'efh/w-1020', 'тепловентилятор'],
#  ['electrolux', 'efh/w-9020', 'тепловентилятор'],
#  ['electrolux', 'ehda/bh-800', 'сушилка', 'для', 'рук'],
#  ['ballu', 'bfh/с-29,', 'white', 'тепловентилятор'],
#  ['stadler',
#   'form',
#   'oskar',
#   'big',
#   'o-040r,',
#   'white',
#   'увлажнитель',
#   'воздуха'],
#  ['boneco', 'u700', 'ультразвуковой', 'увлажнитель', 'воздуха'],
#  ['electrolux', 'ehu-3810d', 'yogahealthline', 'увлажнитель-ecobiocomplex'],
#  ['ручка',
#   'капиллярная',
#   'с',
#   'регулятором',
#   'xtra',
#   '823,',
#   '0,3',
#   'мм;',
#   'синий',
#   'цвет',
#   'чернил.'],
#  ['ручка', 'гелевая', 'pilot', '"g-1",', 'цвет:', 'синий'],
#  ['ручка', 'гелевая', 'pilot', '"g-1",', 'цвет:', 'черный'],
#  ['ручка', 'шариковая', 'pilot,', 'цвет:', 'красный'],
#  ['набор', 'капиллярных', 'ручек', '"stabilo', 'point",', '10', 'шт'],
#  ['ручка', 'гелевая', 'pilot', '"super', 'gel",', 'цвет:', 'синий'],
#  ['ручка',
#   'шариковая',
#   'erich',
#   'krause',
#   '"grapho:',
#   'semi-gel",',
#   'цвет:',
#   'синий'],
#  ['ручка',
#   'гелевая',
#   'erich',
#   'crause',
#   '"megapolis',
#   'gel",',
#   'цвет:',
#   'черный'],
#  ['ручка', 'шариковая', 'pilot', '"bps-gp-fine",', 'цвет:', 'синий'],
#  ['ручка', 'шариковая', 'pilot', '"bps-gp-fine",', 'цвет:', 'черный'],
#  ['набор', 'капиллярных', 'ручек', 'stabilo', '"point', '88",', '3', 'шт'],
#  ['ручка',
#   'гелевая',
#   'stabilo',
#   '"easy',
#   'gel",',
#   'для',
#   'правшей.',
#   'b-40004-10'],
#  ['шар.ручка', 'черный', 'стержень', '0.7мм', 'в', 'блистере'],
#  ['набор', 'ручек', '"greenpoint",', '4', 'цвета'],
#  ['zebra', 'маркер', 'перманентный', 'paint', 'белый'],
#  ['pentel',
#   'гелевая',
#   'ручка',
#   'hybrid',
#   'gel',
#   'grip',
#   'цвет',
#   'чернил',
#   'черный'],
#  ['berlingo', 'ручка', 'шариковая', 'pr-05', 'синяя'],
#  ['berlingo', 'ручка', 'шариковая', 'mega', 'soft', 'черная'],
#  ['berlingo', 'ручка', 'шариковая', 'mega', 'soft', 'синяя'],
#  ['pentel', 'гелевая', 'ручка', 'energel', 'цвет', 'зеленый'],
#  ['luxor',
#   'набор',
#   'шариковых',
#   'ручек',
#   'stripes',
#   'цвет',
#   'чернил',
#   'синий',
#   '10',
#   'шт'],
#  ['капиллярные',
#   'ручки',
#   'manga,',
#   'набор',
#   'цветов,',
#   'в',
#   'футляре,',
#   '6',
#   'шт.'],
#  ['berlingo',
#   'ручка',
#   'шариковая',
#   'silver',
#   'arrow',
#   'цвет',
#   'корпуса',
#   'черный',
#   'серебристый'],
#  ['luxor', 'набор', 'канцелярский', '5', 'предметов'],
#  ['ручка',
#   'капиллярная',
#   '"v5-ball',
#   'grip",',
#   'цвет:',
#   'синий.',
#   'bln-vbg5-l'],
#  ['cello', 'шариковая', 'ручка', 'gripper', 'цвет', 'чернил', 'красный'],
#  ['berlingo',
#   'ручка',
#   'шариковая',
#   'triangle',
#   '110',
#   'цвет',
#   'чернил',
#   'красный'],
#  ['parker',
#   'ручка',
#   'шариковая',
#   'sonnet',
#   'slim',
#   'matte',
#   'black',
#   'gt',
#   'цвет',
#   'чернил',
#   'черный'],
#  ['berlingo',
#   'ручка',
#   'шариковая',
#   'silk',
#   'standard',
#   'цвет',
#   'корпуса',
#   'синий',
#   'серебристый'],
#  ['officespace', 'набор', 'шариковых', 'цветных', 'ручек', '10', 'шт'],
#  ['officespace', 'набор', 'шариковых', 'ручек', '4', 'цвета'],
#  ['berlingo', 'ручка', 'шариковая', 'western', 'цвет', 'синий'],
#  ['pentel',
#   'гелевая',
#   'ручка',
#   'hybrid',
#   'technica',
#   'цвет',
#   'чернил',
#   'синий'],
#  ['berlingo', 'ручка', 'шариковая', 'pr-07', 'цвет', 'синий'],
#  ['pentel', 'гелевая', 'ручка', '"oh!gel",', 'цвет:', 'красный'],
#  ['pilot',
#   'набор',
#   'шариковых',
#   'ручек',
#   'bps-gp',
#   'цвет',
#   'синий',
#   '3',
#   'шт'],
#  ['berlingo',
#   'ручка',
#   'шариковая',
#   'classic',
#   'pro',
#   'цвет',
#   'чернил',
#   'черный'],
#  ['pentel', 'гелевая', 'ручка', 'с', 'мягкой', 'зоной', 'захвата', 'черная'],
#  ['pentel', 'гелевая', 'ручка', '"energel",', 'цвет:', 'черный'],
#  ['officespace',
#   'набор',
#   'шариковых',
#   'ручек',
#   'school',
#   'цвет',
#   'синий',
#   '12',
#   'шт'],
#  ['berlingo', 'ручка', 'шариковая', 'mp', 'синяя'],
#  ['zebra', 'ручка-роллер', 'be-&', 'ax7', 'цвет', 'чернил', 'черный'],
#  ['berlingo', 'ручка', 'шариковая', 'triangle', 'velvet', 'цвет', 'синий'],
#  ['zebra', 'ручка-роллер', 'be-&', 'ax7', 'цвет', 'чернил', 'синий'],
#  ['berlingo', 'ручка', 'шариковая', 'v-25', 'цвет', 'чернил', 'синий'],
#  ['berlingo', 'ручка', 'гелевая', 'techno-gel', 'красная'],
#  ['berlingo', 'ручка', 'гелевая', 'techno-gel', 'grip', 'синяя'],
#  ['officespace',
#   'набор',
#   'шариковых',
#   'ручек',
#   'zeta',
#   'цвет',
#   'синий',
#   '12',
#   'шт'],
#  ['berlingo', 'ручка', 'гелевая', 'standard', 'черная'],
#  ['pilot', 'ручка', 'шариковая', 'acroball', 'цвет', 'корпуса', 'синий'],
#  ['pilot', 'ручка', 'шариковая', 'acroball', 'цвет', 'корпуса', 'черный'],
#  ['pilot', 'ручка', 'шариковая', 'bp-s', 'цвет', 'чернил', 'синий'],
#  ['mazari', 'набор', 'гелевых', 'ручек', 'orion', '4', 'цвета'],
#  ['faber-castell', 'ручка', 'шариковая', '1430', 'цвет', 'чернил', 'синий'],
#  ['brauberg', 'ручка', 'шариковая', 'настольная', 'синяя'],
#  ['brauberg', 'набор', 'гелевых', 'ручек', 'jet', '6', 'шт'],
#  ['pilot',
#   'ручка',
#   'гелевая',
#   'frixion',
#   'ball',
#   'со',
#   'стираемыми',
#   'чернилами',
#   'черная'],
#  ['pilot', 'ручка', 'гелевая', 'g-3', 'цвет', 'чернил', 'черный'],
#  ['brauberg', 'набор', 'гелевых', 'ручек', 'jet', '10', 'шт'],
#  ['bic', 'ручка', 'шариковая', 'round', 'stic', 'синяя'],
#  ['calligrata', 'ручка', 'шариковая', 'красная'],
#  ['bic', 'ручка', 'гелевая', 'crystal', 'gel', 'черная'],
#  ['calligrata', 'ручка', 'шариковая', 'синяя'],
#  ['index', 'ручка', 'шариковая', 'alpha', 'grip', 'синяя'],
#  ['index', 'набор', 'шариковых', 'ручек', '4', 'цвета'],
#  ['beifa', 'ручка', 'шариковая', '927', 'синяя'],
#  ['beifa', 'ручка', 'шариковая', 'nanoslick', 'new', 'та', '3176-bl', 'синяя'],
#  ['beifa', 'ручка', 'шариковая', 'аа', '927gr', 'зеленая'],
#  ['parker',
#   'ручка',
#   'шариковая',
#   'im',
#   'black',
#   'ct',
#   'цвет',
#   'черный',
#   'серебристый'],
#  ['beifa', 'ручка', 'шариковая', 'аа', '960а', 'синяя'],
#  ['beifa', 'ручка', 'шариковая', 'stop', 'pen', 'на', 'липучке', 'синяя'],
#  ['bic', 'ручка', 'шариковая', 'round', 'stic', 'clic', 'синяя'],
#  ['first',
#   'набор',
#   'гелевых',
#   'ручек',
#   '4',
#   'цвета',
#   'цвет',
#   'корпуса',
#   'белый'],
#  ['bic', 'ручка', 'шариковая', 'round', 'stic', 'exact', 'синяя'],
#  ['cello', 'ручка', 'шариковая', 'slipo', 'синяя'],
#  ['chifon', 'ручка', 'гелевая', 'черная'],
#  ['crown', 'ручка', 'гелевая', 'hjr-500', 'черная'],
#  ['crown', 'ручка', 'гелевая', 'hjr-500r', 'зеленая'],
#  ['crown', 'ручка', 'гелевая', 'hjr-500rn', 'зеленая'],
#  ['crown', 'ручка', 'шариковая', 'oj-500', 'синяя'],
#  ['deli', 'ручка', 'гелевая', 'цвет', 'корпуса', 'синий', 'синяя'],
#  ['deli',
#   'ручка',
#   'гелевая',
#   'цвет',
#   'корпуса',
#   'прозрачный',
#   'синяя',
#   '2308404'],
#  ['deli', 'ручка', 'шариковая', 'красная'],
#  ['erich', 'krause', 'ручка', 'гелевая', 'g-tone', 'ek', 'красная'],
#  ['erich',
#   'krause',
#   'ручка',
#   'гелевая',
#   'g-tone',
#   'ek',
#   'цвет',
#   'корпуса',
#   'черный'],
#  ['erich', 'krause', 'ручка', 'шариковая', 'r-101', 'ek', 'синяя'],
#  ['erich', 'krause', 'ручка', 'шариковая', 'ultra', 'l-30', 'ek', 'синяя'],
#  ['ручка', 'гелевая', 'красная', '1512096'],
#  ['erich', 'krause', 'ручка', 'шариковая', 'r-301', 'grip', 'синяя'],
#  ['ручка', 'гелевая', 'черная', '714395'],
#  ['ручка', 'гелевая', 'синяя', '546722'],
#  ['erich', 'krause', 'ручка', 'шариковая', 'r-301', 'matic', 'синяя'],
#  ['ручка', 'гелевая', 'синяя', '233541'],
#  ['stabilo',
#   'ручка',
#   'шариковая',
#   'liner',
#   '808',
#   'цвет',
#   'чернил',
#   'зеленый'],
#  ['erich', 'krause', 'ручка', 'шариковая', 'r-301', 'orange', 'ek', 'синяя'],
#  ['stabilo', 'ручка', 'шариковая', 'liner', '808', 'синяя', '1060339'],
#  ['союз', 'ручка', 'гелевая', 'оскар', 'красная'],
#  ['erich',
#   'krause',
#   'ручка',
#   'шариковая',
#   'r-301',
#   'orange',
#   'stick',
#   'ek',
#   'синяя'],
#  ['союз', 'ручка', 'гелевая', 'оскар', 'черная'],
#  ['vinson', 'ручка', 'шариковая', 'синяя'],
#  ['ручка', 'шариковая', 'стразы', 'цвет', 'корпуса', 'розовый'],
#  ['ручка', 'шариковая', 'wx-583', 'красная'],
#  ['стамм', 'ручка', 'шариковая', '049', 'синяя'],
#  ['ручка', 'шариковая', 'а100', 'синяя'],
#  ['стамм', 'ручка', 'шариковая', '111', 'офис', 'синяя'],
#  ['xms', 'ручка', 'шариковая', 'синяя'],
#  ['ручка',
#   'шариковая',
#   'munhwa',
#   'mc',
#   'gold',
#   'синяя,',
#   '0,5мм,',
#   'грип,',
#   '207858'],
#  ['стамм', 'ручка', 'шариковая', '555', 'синяя'],
#  ['стержень', 'для', 'шариковой', 'ручки', 'цвет', 'синий', '634791'],
#  ['стержень', 'для', 'шариковой', 'ручки', 'цвет', 'синий'],
#  ['стамм', 'ручка', 'шариковая', 'оптима', 'orange', 'синяя'],
#  ['pentel',
#   'ручка',
#   'шариковая',
#   'feel',
#   'it',
#   'цвет',
#   'чернил',
#   'красный',
#   '0,5',
#   'мм'],
#  ['стамм', 'ручка', 'шариковая', 'оптима', 'цвет', 'чернил', 'синий'],
#  ['pentel',
#   'ручка',
#   'шариковая',
#   'feel',
#   'it',
#   'цвет',
#   'чернил',
#   'синий',
#   '0,5',
#   'мм'],
#  ['parker', 'ручка-роллер', 'urban', 'metro', 'metallic', 'ct', 'черная'],
#  ['союз', 'ручка', 'гелевая', 'comfort', 'зеленая'],
#  ['союз', 'ручка', 'гелевая', 'comfort', 'черная'],
#  ['ручка', 'шариковая', 'цвет', 'корпуса', 'прозрачный', '167058'],
#  ['parker',
#   'картридж',
#   'с',
#   'чернилами',
#   'quink',
#   'long',
#   'для',
#   'перьевой',
#   'ручки',
#   'цвет',
#   'темно-синий',
#   '5',
#   'шт'],
#  ['crown', 'ручка', 'гелевая', 'пастель', 'белая'],
#  ['crown', 'ручка', 'гелевая', 'металлик', 'золотая'],
#  ['ручка', 'гелевая', 'цвет', 'чернил', 'черный'],
#  ['ручка', 'гелевая', 'с', 'держателем', 'черная'],
#  ['faber-castell',
#   'ручка-роллер',
#   'сx7',
#   '0,7',
#   'мм',
#   'цвет',
#   'чернил',
#   'красный'],
#  ['faber-castell',
#   'ручка-роллер',
#   'сx7',
#   '0,7',
#   'мм',
#   'цвет',
#   'чернил',
#   'синий'],
#  ['crown', 'ручка', 'гелевая', 'красная'],
#  ['pentel',
#   'ручка',
#   'гелевая',
#   'hybrid',
#   'gel',
#   'grip',
#   'цвет',
#   'чернил',
#   'белый'],
#  ['staedtler',
#   'ручка',
#   'шариковая',
#   'ball',
#   '0,3',
#   'мм',
#   'цвет',
#   'чернил',
#   'зеленый'],
#  ['crown', 'ручка', 'гелевая', 'синяя'],
#  ['staedtler',
#   'шариковая',
#   'ручка',
#   'ball,',
#   'm',
#   '0,5',
#   'мм,',
#   'цвет',
#   'красный'],
#  ['crown', 'ручка', 'гелевая', 'черная'],
#  ['erich',
#   'krause',
#   'ручка',
#   'шариковая',
#   'r-301',
#   'orange',
#   '0.7',
#   'stick',
#   'черная',
#   '39032'],
#  ['erich',
#   'krause',
#   'набор',
#   'стержней',
#   'для',
#   'шариковой',
#   'ручки',
#   'цвет',
#   'синий',
#   '0,7',
#   'мм',
#   '10',
#   'шт'],
#  ['стамм',
#   'набор',
#   'стержней',
#   'для',
#   'шариковой',
#   'ручки',
#   'цвет',
#   'синий',
#   '0,7',
#   'мм',
#   '10',
#   'шт'],
#  ['berlingo', 'ручка', 'шариковая', 'xgold', 'цвет', 'чернил', 'синий'],
#  ['berlingo', 'ручка', 'шариковая', 'xgold', 'цвет', 'чернил', 'черный'],
#  ['berlingo', 'ручка', 'гелевая', 'g-line', 'цвет', 'чернил', 'синий'],
#  ['berlingo', 'ручка', 'гелевая', 'g-line', 'цвет', 'чернил', 'красный'],
#  ['berlingo', 'ручка', 'гелевая', 'velvet', 'цвет', 'чернил', 'черный'],
#  ['berlingo', 'ручка', 'гелевая', 'velvet', 'цвет', 'чернил', 'синий'],
#  ['berlingo',
#   'ручка',
#   'гелевая',
#   'classic',
#   'gel',
#   'цвет',
#   'чернил',
#   'черный'],
#  ['эврика', 'ручка', 'шариковая', 'клюшка', 'для', 'гольфа'],
#  ['faber-castell',
#   'набор',
#   'капиллярных',
#   'ручек',
#   'ecco',
#   'pigment',
#   'цвет',
#   'чернил',
#   'черный',
#   '4',
#   'шт'],
#  ['stabilo', 'ручка-роллер', 'bionic', 'синяя'],
#  ['pilot', 'ручка', 'гелевая', 'p500', 'цвет', 'чернил', 'фиолетовый'],
#  ['stabilo', 'ручка', 'шариковая', 're-liner', '868', 'f', 'синяя'],
#  ['bic', 'ручка', 'шариковая', 'orange', 'grip', 'цвет', 'чернил', 'синий'],
#  ['centrum',
#   'набор',
#   'карандашей',
#   'смешарики',
#   'с',
#   'точилкой',
#   '12',
#   'цветов'],
#  ['карандаш',
#   'чернографитный',
#   'деревянный',
#   'нв',
#   'заточенный;',
#   'полосатый',
#   'черно',
#   '-',
#   'желтый',
#   'корпус,',
#   'с',
#   'запаянным',
#   'верхом.',
#   '12',
#   'шт.'],
#  ['набор', 'карандашей', 'акварельных', 'mondeluz,', '36', 'цв'],
#  ['faber-castell',
#   'набор',
#   'цветных',
#   'карандашей',
#   'eco',
#   '18',
#   'цветов',
#   'с',
#   'точилкой',
#   'цвет',
#   'точилки',
#   'синий'],
#  ['набор', 'карандашей', 'акварельных', 'mondeluz,', '24', 'цв'],
#  ['набор', 'цветных', 'карандашей', '"stabilo', 'color",', '12', 'цветов'],
#  ['карандаш',
#   'чернографитный',
#   '"таблица',
#   'умножения"',
#   'деревянный',
#   'нв',
#   'заточенный;',
#   'таблица',
#   'умножения',
#   'на',
#   'корпусе,',
#   'с',
#   'ластиком.',
#   '12',
#   'шт.'],
#  ['набор', 'карандашей', 'акварельных', 'mondeluz,', '18', 'цв'],
#  ['акварельные',
#   'карандаши',
#   'art',
#   'grip',
#   'aquarelle,',
#   'набор',
#   'цветов,',
#   'в',
#   'металлической',
#   'коробке,',
#   '24',
#   'шт.'],
#  ['erich', 'krause', 'цветные', 'карандаши,', '24', 'цвета'],
#  ['набор', 'угольных', 'карандашей', 'koh-i-noor', '"gioconda",', '3', 'шт'],
#  ['карандаши',
#   '18',
#   'цветов',
#   '"сибирский',
#   'кедр.',
#   'дикие',
#   'кошки"',
#   '(длина',
#   '175',
#   'мм)',
#   'трехгранные',
#   'в',
#   'картонной',
#   'коробке',
#   'с',
#   'европодвесом,',
#   'ok',
#   '6.9',
#   'мм'],
#  ['карандаши',
#   '24',
#   'цвета',
#   '"русский',
#   'карандаш.',
#   'фольклор"',
#   '(длина',
#   '175',
#   'мм)',
#   'шестигранные',
#   'в',
#   'картонной',
#   'двухрядной',
#   'коробке',
#   'с',
#   'европодвесом,',
#   'ok',
#   '6.4',
#   'мм'],
#  ['карандаши',
#   'цветные,',
#   '18цв.,',
#   'rio,',
#   'шестигранные,',
#   'карт.европодвес',
#   'арт.134189-18',
#   'ед.изм.набор'],
#  ['цветные', 'карандаши', '"животные",', '24', 'цвета'],
#  ['карандаши',
#   'цветные',
#   'двухсторонние',
#   'maped',
#   '"color\'',
#   'peps',
#   'duo",',
#   '12',
#   'карандашей,',
#   '24',
#   'цвета'],
#  ['faber-castell', 'карандаш', 'чернографитовый', 'grip', '2001'],
#  ['faber-castell', 'карандаш', 'чернографитовый', 'grip', '2001', '117200'],
#  ['карандаши', 'цветные', 'maped', '"color\'', 'peps",', '36', 'цветов'],
#  ['цветные', 'карандаши', '"собаки', 'и', 'кошки",', '36', 'цветов'],
# ...
#  ['maped',
#   'набор',
#   'маркеров',
#   'fluo',
#   "pep's",
#   'ultra',
#   'soft',
#   '4',
#   'цвета'],
#  ['vista-artista', 'маркер', 'style', 'цвет', 'океанский', 'зеленый', 'z416'],
#  ['vista-artista', 'маркер', 'style', 'цвет', 'серый', 'теплый', '2', 's487'],
#  ['vista-artista', 'маркер', 'style', 'цвет', 'z465', 'светло-хаки'],
#  ['vista-artista', 'маркер', 'style', 'цвет', 'слоновая', 'кость', 'j101'],
#  ['vista-artista', 'маркер', 'style', 'цвет', 'k226', 'алый'],
#  ['staedtler', 'маркер', 'triplus', 'цвет', 'красный', '3451-2'],
#  ['vista-artista', 'маркер', 'style', 'цвет', 'b100', 'черный'],
#  ['vista-artista', 'маркер', 'style', 'цвет', 'мятно-голубой', 'g343'],
#  ['vista-artista',
#   'маркер',
#   'style',
#   'цвет',
#   'светлый',
#   'розово-бежевый',
#   'k247'],
#  ['vista-artista', 'маркер', 'style', 'цвет', 'j149', 'светло-оранжевый'],
#  ['набор', 'фломастеров', '"веселые', 'животные",', '18', 'цветов'],
#  ['набор', 'смываемых', 'фломастеров', '"centropen",', '12', 'цветов'],
#  ['centropen', 'набор', 'фломастеров', 'слон', '30', 'цветов'],
#  ['набор', 'цветных', 'фломастеров,', '12', 'шт', 'barbie'],
#  ['набор',
#   'фломастеров',
#   'power',
#   'max',
#   '12',
#   'цв,',
#   'пластиковый',
#   'футляр'],
#  ['faber-castell', 'фломастеры', 'jumbo', '24', 'цвета'],
#  ['faber-castell', 'набор', 'фломастеров', '12', 'шт'],
#  ['silwerhof', 'фломастеры', 'народная', 'коллекция', '18', 'цветов'],
#  ['berlingo', 'набор', 'фломастеров', 'жил-был', 'кот', '6', 'цветов'],
#  ['berlingo', 'набор', 'фломастеров', 'жил-был', 'кот', '12', 'цветов'],
#  ['silwerhof',
#   'фломастеры',
#   'джинсовая',
#   'коллекция',
#   '12',
#   'цветов',
#   '867209-12'],
#  ['action!', 'набор', 'фломастеров', '6', 'цветов'],
#  ['action!', 'набор', 'фломастеров', '18', 'цветов'],
#  ['berlingo', 'набор', 'фломастеров', 'замки', '18', 'цветов'],
#  ['micador', 'фломастеры', '12', 'цветов'],
#  ['пифагор', 'набор', 'фломастеров', '6', 'цветов'],
#  ['koh-i-noor', 'набор', 'фломастеров', 'утята', '18', 'цветов'],
#  ['maped', 'набор', 'фломастеров', 'colorpeps', 'ocean', '18', 'цветов'],
#  ['giotto', 'набор', 'фломастеров', 'turbo', 'color', '12', 'цветов'],
#  ['maped',
#   'набор',
#   'двусторонних',
#   'фломастеров',
#   'duo',
#   '10',
#   'шт',
#   '20',
#   'цветов'],
#  ['maped', 'набор', 'фломастеров', 'jungle', 'смываемые', '18', 'цветов'],
#  ['faber-castell',
#   'набор',
#   'фломастеров',
#   'connector',
#   'машина',
#   'с',
#   'клипами',
#   '33',
#   'цвета'],
#  ['тетрадь',
#   'с',
#   'твердой',
#   'обложкой',
#   '96л',
#   'а5ф',
#   'клетка',
#   'на',
#   'гребне',
#   'london'],
#  ['тетрадь', 'на', 'спирали', 'а5+,', '96л', 'spiral', 'block', '3,', 'синий'],
#  ['academy',
#   'style',
#   'тетрадь',
#   'в',
#   'клетку',
#   '"геральдика",',
#   '96',
#   'листов,',
#   'формат',
#   'а5'],
#  ['полиграфика',
#   'тетрадь',
#   'цветы',
#   'в',
#   'узорах',
#   '96',
#   'листов',
#   'в',
#   'клетку',
#   'цвет',
#   'голубой'],
#  ['полиграфика', 'тетрадь', 'классика', '12', 'листов', 'в', 'клетку'],
#  ['hatber',
#   'тетрадь',
#   'mono',
#   'colour',
#   '96',
#   'листов',
#   'в',
#   'клетку',
#   'цвет',
#   'синий'],
#  ['тетрадь',
#   'в',
#   'клетку',
#   'hatber',
#   '"океан",',
#   '96',
#   'листов.',
#   'формат',
#   'а4'],
#  ['faber-castell',
#   'карандаш',
#   'чернографитный',
#   'castell',
#   '9000',
#   'твердость',
#   '4b'],
#  ['faber-castell',
#   'карандаш',
#   'механический',
#   'grip-matic',
#   'цвет',
#   'корпуса',
#   'красный',
#   '137721'],
#  ['bic',
#   'набор',
#   'чернографитных',
#   'карандашей',
#   'evolution',
#   'с',
#   'ластиком',
#   '4',
#   'шт'],
#  ['faber-castell', 'карандаш', 'чернографитовый', 'castell', '9000', '119200'],
#  ['faber-castell',
#   'карандаш',
#   'чернографитовый',
#   'castell',
#   '9000',
#   'твердость',
#   'b'],
#  ['набор',
#   'чернографитовых',
#   'карандашей',
#   '"koh-i-noor",',
#   '2н,',
#   'н,',
#   'нв,',
#   'в,',
#   '2в,',
#   '6',
#   'шт.',
#   '126738'],
#  ['faber-castell', 'графитные', 'грифели', 'polymer', '12', 'шт'],
#  ['berlingo', 'набор', 'цветных', 'карандашей', 'замки', '18', 'шт'],
#  ['action!', 'набор', 'цветных', 'карандашей', '12', 'цветов'],
#  ['faber-castell',
#   'набор',
#   'цветных',
#   'акварельных',
#   'карандашей',
#   'albrecht',
#   'durer',
#   '24',
#   'цвета'],
#  ['berlingo', 'набор', 'чернографитных', 'карандашей', '3', 'шт'],
#  ['stabilo', 'набор', 'акварельных', 'карандашей', 'aquacolor', '24', 'цвета'],
#  ['lyra', 'карандаш', 'чернографитный', 'studium', 'твердость', 'hb'],
#  ['пифагор', 'набор', 'цветных', 'карандашей', '12', 'цветов'],
#  ['koh-i-noor', 'набор', 'цветных', 'карандашей', 'polycolor', '24', 'шт'],
#  ['erich', 'krause', 'карандаш', 'механический', 'megapolis', 'concept'],
#  ['пифагор', 'набор', 'цветных', 'карандашей', '24', 'цвета'],
#  ['erich', 'krause', 'карандаш', 'механический', 'delta'],
#  ['deli', 'набор', 'чернографитных', 'карандашей', '12', 'шт'],
#  ['пифагор', 'набор', 'восковых', 'карандашей', '6', 'цветов'],
#  ['koh-i-noor', 'набор', 'чернографитных', 'карандашей', '3', 'шт'],
#  ['красин', 'карандаш', 'чернографитный', 'номер', 'один', 'твердость', 'b'],
#  ['скф',
#   'набор',
#   'цветных',
#   'карандашей',
#   'сибирский',
#   'кедр',
#   'дикие',
#   'кошки',
#   '12',
#   'шт'],
#  ['карандаш',
#   'чернографитный',
#   'с',
#   'ластиком',
#   'цвет',
#   'корпуса',
#   'красный',
#   'серый'],
#  ['русский', 'карандаш', 'карандаш', 'чернографитный', 'твердость', 'h'],
#  ['staedtler', 'карандаш', 'lumograph', '100', '2в'],
#  ['русский',
#   'карандаш',
#   'карандаш',
#   'чернографитный',
#   'русский',
#   'карандаш',
#   'твердость',
#   '2h'],
#  ['русский',
#   'карандаш',
#   'карандаш',
#   'чернографитный',
#   'русский',
#   'карандаш',
#   'твердость',
#   'hb'],
#  ['скф',
#   'набор',
#   'цветных',
#   'карандашей',
#   'русский',
#   'карандаш',
#   'сказки',
#   '24',
#   'шт'],
#  ['сибирский',
#   'кедр',
#   'карандаш',
#   'чернографитный',
#   'сибирский',
#   'кедр',
#   'цвет',
#   'корпуса',
#   'синий'],
#  ['сибирский',
#   'кедр',
#   'карандаш',
#   'чернографитный',
#   'цвет',
#   'корпуса',
#   'зеленый'],
#  ['maped', 'карандаш', 'чернографитный', 'black', "pep's"],
#  ['staedtler', 'карандаш', 'noris', 'нв', 'с', 'ластиком'],
#  ['красин',
#   'карандаш',
#   'чернографитный',
#   'конструктор',
#   'винтаж',
#   'твердость',
#   'b'],
#  ['мульти-пульти',
#   'набор',
#   'акварельных',
#   'карандашей',
#   'енот',
#   'в',
#   'карибском',
#   'море',
#   '6',
#   'цветов'],
#  ['faber-castell',
#   'грифель',
#   'для',
#   'механического',
#   'карандаша',
#   'superpolymer',
#   'hb',
#   '0,7',
#   'мм',
#   '12',
#   'шт'],
#  ['dolce', 'карандаш', 'чернографитный', 'с', 'ластиком'],
#  ['faber-castell',
#   'грифель',
#   'для',
#   'механического',
#   'карандаша',
#   'polymer',
#   'hb',
#   '0,5',
#   'мм',
#   '12',
#   'шт'],
#  ['faber-castell',
#   'грифель',
#   'для',
#   'механического',
#   'карандаша',
#   'polymer',
#   'h',
#   '0,5',
#   'мм',
#   '12',
#   'шт'],
#  ['faber-castell', 'карандаш', 'чернографитный', 'design'],
#  ['faber-castell',
#   'карандаш',
#   'чернографитный',
#   'goldfaber',
#   '1222',
#   '2b',
#   'с',
#   'ластиком'],
#  ['сибирская',
#   'карандашная',
#   'фабрика',
#   'набор',
#   'чернографитных',
#   'карандашей',
#   'сибирский',
#   'кедр',
#   'работа',
#   'не',
#   'волк',
#   '6',
#   'шт'],
#  ['faber-castell',
#   'карандаш',
#   'чернографитный',
#   'goldfaber',
#   '1222',
#   'hb',
#   'с',
#   'ластиком'],
#  ['erich',
#   'krause',
#   'карандаш',
#   'чернографитный',
#   'megapolis',
#   '101',
#   'с',
#   'ластиком',
#   '32860'],
#  ['staedtler', 'карандаш', 'чернографитный', 'wopex', 'твердость', 'hb'],
#  ['staedtler', 'карандаш', 'чернографитный', 'noris', 'твердость', 'hb'],
#  ['маркер', 'перманентный', '"lacquer",', 'цвет:', 'белый'],
#  ['centropen', 'набор', 'перманентных', 'маркеров', '4', 'цвета'],
#  ['набор', 'текстмаркеров', '"index",', '4', 'цвета.', 'imh505/4'],
#  ['набор', 'текстмаркеров', '"highlighter', 'visioline",', '4', 'шт'],
#  ['набор', 'маркеров', '"magnetoplan",', '4', 'цвета.', '12281'],
#  ['набор', 'маркеров', '"magnetoplan",', '4', 'шт'],
#  ['faber-castell', 'набор', 'текстовыделителей', 'textliner', '4', 'цвета'],
#  ['набор', 'текстовыделителей.', 'нетоксичные'],
#  ['маркер', '"pentel",', 'для', 'досок,', 'цвет:', 'черный'],
#  ['officespace', 'текстовыделитель', 'цвет', 'зеленый', 'h_262'],
#  ['pentel', 'маркер', 'перманентный', '"paint', 'marker",', 'цвет:', 'белый'],
#  ['faber-castell', 'текстовыделитель', '4', 'цвета'],
#  ['officespace', 'набор', 'текстовыделителей', '4', 'цвета', 'h4_6542'],
#  ['pentel', 'маркер', 'перманентный', '"paint', 'marker",', 'цвет:', 'золото'],
#  ['mazari', 'маркер', 'перманентный', 'harmony', 'цвет', 'черный'],
#  ['officespace', 'маркер', 'для', 'доски', 'цвет', 'черный'],
#  ['officespace', 'набор', 'маркеров', 'для', 'белых', 'досок', '4', 'цвета'],
#  ['baramba', 'набор', 'текстовыделителей', '4', 'цвета'],
#  ['schneider', 'набор', 'маркеров', '151', '4', 'цвета'],
#  ['oxford',
#   'тетрадь',
#   'international',
#   'easybook',
#   '80',
#   'листов',
#   'в',
#   'клетку',
#   'формат',
#   'а4+'],
#  ['кпк',
#   'тетрадь',
#   '24',
#   'листа',
#   'в',
#   'линейку',
#   'цвет',
#   'зеленый',
#   '679447'],
#  ['кпк', 'тетрадь', '24', 'листа', 'в', 'клетку', 'цвет', 'зеленый'],
#  ['кпк', 'тетрадь', '18', 'листов', 'в', 'линейку', 'цвет', 'зеленый'],
#  ['кпк', 'тетрадь', '12', 'листов', 'в', 'линейку', 'цвет', 'зеленый'],
#  ['проф-пресс',
#   'тетрадь',
#   'города',
#   'и',
#   'газета',
#   '96',
#   'листов',
#   'в',
#   'клетку'],
#  ['staff', 'тетрадь', 'города', 'венеция', '48', 'листов', 'в', 'клетку'],
#  ['полином', 'тетрадь', 'с', 'разделителями', '120', 'листов', 'в', 'клетку'],
#  ['hatber', 'тетрадь', 'emotion', '100', 'листов', 'в', 'клетку'],
#  ['кфоб', 'тетрадь', '24', 'листа', 'в', 'линейку', 'цвет', 'зеленый'],
#  ['кпк',
#   'тетрадь',
#   '12',
#   'листов',
#   'в',
#   'косую',
#   'линейку',
#   'цвет',
#   'зеленый',
#   '777968'],
#  ['hatber',
#   'тетрадь',
#   'аквалайф',
#   '96',
#   'листов',
#   'в',
#   'клетку',
#   'цвет',
#   'оранжевый'],
#  ['тетрадь', 'орнамент', '48', 'листов', 'в', 'клетку'],
#  ['альт',
#   'тетрадь',
#   'народная',
#   '12',
#   'листов',
#   'в',
#   'узкую',
#   'линейку',
#   'цвет',
#   'салатовый'],
#  ['brauberg',
#   'тетрадь',
#   'классика',
#   '12',
#   'листов',
#   'в',
#   'крупную',
#   'клетку',
#   'цвет',
#   'зеленый'],
#  ['brauberg',
#   'тетрадь',
#   'классика',
#   '12',
#   'листов',
#   'в',
#   'крупную',
#   'клетку',
#   'цвет',
#   'желтый'],
#  ['walker', 'рюкзак', 'trolley', 'fun', 'spring', 'fever'],
#  ['magtaller', 'ранец', 'школьный', 'ранец', 'ezzy', 'ii', 'sewing', 'hearts'],
#  ['herlitz',
#   'ранец',
#   'школьный',
#   'spaceshuttle',
#   'с',
#   'наполнением',
#   '3',
#   'предмета'],
#  ['brauberg', 'рюкзак', 'райдер'],
#  ['greenwich',
#   'line',
#   'тетрадь',
#   'one',
#   'color',
#   '48',
#   'листов',
#   'в',
#   'линейку',
#   'цвет',
#   'фиолетовый'],
#  ['brauberg', 'тетрадь', 'экология', 'лист', '48', 'листов', 'в', 'клетку'],
#  ['канц-эксмо',
#   'тетрадь',
#   'яркое',
#   'настроение',
#   '48',
#   'листов',
#   'в',
#   'клетку'],
#  ['канц-эксмо',
#   'тетрадь',
#   'мировые',
#   'достопримечательности',
#   '96',
#   'листов',
#   'в',
#   'клетку'],
#  ['бумага', 'масштабно-координатная', '"hatber",', '16', 'листов.', '2284'],
#  ['листы',
#   'для',
#   'пастелей',
#   'palazzo',
#   '"италия",',
#   'а3,',
#   'цвет:',
#   'слоновая',
#   'кость,',
#   '10',
#   'листов'],
#  ['альбом',
#   'для',
#   'рисования',
#   'акварелью',
#   '"kroyter",',
#   '10',
#   'листов,',
#   'формат',
#   'а4'],
#  ['альбом', 'для', 'пастели', '"kroyter",', '10', 'листов,', 'формат', 'а3'],
#  ['альбом', 'для', 'пастели', '"kroyter",', '10', 'листов,', 'формат', 'а4'],
#  ['папка', 'для', 'акварели', '"флора",', '10', 'листов,', 'формат', 'а3'],
#  ['гознак', 'папка', 'для', 'черчения', 'школьная', '24', 'листа'],
#  ['папка',
#   'для',
#   'черчения',
#   '"гознак",',
#   'с',
#   'вертикальной',
#   'рамкой,',
#   '10',
#   'листов,',
#   'формат',
#   'а3'],
#  ['альбом',
#   'для',
#   'рисования',
#   'акварелью',
#   '"kroyter",',
#   '20',
#   'листов,',
#   'формат',
#   'а3'],
#  ['картон', 'hatber', '"creative', 'set",', 'цвет:', 'белый,', '10', 'листов'],
#  ['папка', 'для', 'акварели', '"kroyter",', '20', 'листов,', 'формат', 'а4'],
#  ['папка',
#   'для',
#   'черчения',
#   'kroyter',
#   '"western",',
#   '20',
#   'листов,',
#   'формат',
#   'а3'],
#  ['папка',
#   'для',
#   'черчения',
#   'kroyter',
#   '"город",',
#   '10',
#   'листов,',
#   'формат',
#   'а3'],
#  ['альбом',
#   'для',
#   'черчения',
#   'hatber',
#   '"архитектура",',
#   '20',
#   'листов.',
#   'формат',
#   'а4'],
#  ['альбом',
#   'для',
#   'рисования',
#   'акварелью',
#   '"kroyter",',
#   '20',
#   'листов,',
#   'формат',
#   'а4'],
#  ['папка',
#   'для',
#   'акварели',
#   '"kroyter",',
#   '10',
#   'листов,',
#   'формат',
#   'а3.',
#   '05688'],
#  ['папка',
#   'для',
#   'рисования',
#   'и',
#   'эскизов',
#   '"kroyter",',
#   '20',
#   'листов,',
#   'формат',
#   'а3'],
#  ['бумага',
#   'масштабно-координатная',
#   '"hatber",',
#   '8',
#   'листов,',
#   'формат',
#   'а3.',
#   '8бм3_02285'],
#  ['hatber',
#   'набор',
#   'цветной',
#   'самоклеящейся',
#   'бумаги',
#   'creative',
#   'set',
#   '10',
#   'листов'],
#  ['альбом',
#   'для',
#   'рисования',
#   'с',
#   'бумагой',
#   'для',
#   'акварели',
#   'erich',
#   'krause',
#   '"дом',
#   'у',
#   'моря",',
#   '20',
#   'листов.',
#   '37168'],
#  ['цветной',
#   'картон',
#   'hatber',
#   '"подводный',
#   'мир",',
#   'двусторонний,',
#   '10',
#   'цветов'],
#  ['цветная',
#   'бумага',
#   'для',
#   'рукоделия',
#   'palazzo',
#   '"басня",',
#   '30',
#   'листов,',
#   '10',
#   'цветов,',
#   'формат',
#   'а4'],
#  ['папка',
#   'для',
#   'пастели',
#   'и',
#   'акварели/планшет',
#   'а3,',
#   '20',
#   'листов,',
#   '2',
#   'цвета,',
#   '200',
#   'г/м2,',
#   'тонированная',
#   'бумага,',
#   '«венеция»,',
#   'пл-6457'],
#  ['milan',
#   'набор',
#   'ластиков',
#   '124',
#   'цвет',
#   'зеленый',
#   'красный',
#   '3',
#   'шт'],
#  ['staedtler', 'линейка', 'цвет', 'прозрачный', '40', 'см'],
#  ['faber-castell', 'ластик', 'виниловый', 'dust-free', '187120'],
#  ['faber-castell', 'ластик', 'dust-free', 'цвет', 'белый'],
#  ['проф-пресс',
#   'классный',
#   'журнал',
#   'для',
#   '10-11',
#   'классов',
#   '92',
#   'листа'],
#  ['artspace', 'альбом', 'для', 'рисования', 'мультяшки', '20', 'листов'],
#  ['silwerhof',
#   'цветная',
#   'бумага',
#   'металлизированная',
#   'shine',
#   'flyers',
#   '5',
#   'листов',
#   '5',
#   'цветов'],
#  ['sadipal', 'бумага', 'цветная', 'глянцевая', '10', 'листов'],
#  ['апплика', 'цветная', 'бумага', 'пеликан', '8', 'листов'],
#  ['апплика', 'цветной', 'картон', 'медведь', '10', 'листов'],
#  ['апплика',
#   'бумага',
#   'для',
#   'черчения',
#   'дом',
#   '10',
#   'листов',
#   'формат',
#   'а3'],
#  ['бриз', 'бумага', 'цветная', 'двухсторонняя', '10', 'листов'],
#  ['palazzo',
#   'альбом',
#   'для',
#   'рисования',
#   'белая',
#   'роза',
#   '20',
#   'листов',
#   'плбр/а2'],
#  ['бриз', 'бумага', 'цветная', 'двухсторонняя', 'щенок', '16', 'листов'],
#  ['апплика', 'альбом', 'для', 'рисования', 'париж', '24', 'листа'],
#  ['kroyter', 'альбом', 'для', 'рисования', 'акварелью', '40', 'листов'],
#  ['palazzo',
#   'альбом',
#   'для',
#   'рисования',
#   'сладкие',
#   'грезы',
#   '18',
#   'листов',
#   'ппг/а3'],
#  ['палаццо', 'картон', 'цветной', 'натюрморт', '10', 'листов', '10', 'цветов'],
#  ['бриз', 'бумага', 'цветная', '16', 'листов'],
#  ['апплика',
#   'альбом',
#   'для',
#   'рисования',
#   'веселые',
#   'животные',
#   '20',
#   'листов'],
#  ['kroyter',
#   'альбом',
#   'для',
#   'рисования',
#   'пастелью',
#   'цвет',
#   'зеленый',
#   '10',
#   'листов'],
#  ['artspace', 'папка', 'для', 'черчения', '10', 'листов', 'а4'],
#  ['artspace', 'папка', 'для', 'черчения', 'формат', 'а3', '20', 'листов'],
#  ['artspace', 'папка', 'для', 'черчения', '20', 'листов', 'а4'],
#  ['kroyter',
#   'альбом',
#   'для',
#   'рисования',
#   'пастелью',
#   'цвет',
#   'черный',
#   '10',
#   'листов'],
#  ['канц-эксмо',
#   'альбом',
#   'для',
#   'рисования',
#   'цветочные',
#   'силуэты',
#   '40',
#   'листов'],
#  ['trolls', 'картон', 'цветной', 'мелованный', '8', 'листов', '8', 'цветов'],
#  ['artspace',
#   'папка',
#   'для',
#   'черчения',
#   '10',
#   'листов',
#   'с',
#   'вертикальной',
#   'рамкой',
#   'а4'],
#  ['фиксики', 'альбом', 'для', 'рисования', '40', 'листов'],
#  ['albion', 'цветная', 'бумага', '16', 'листов', '8', 'цветов'],
#  ['апплика',
#   'цветная',
#   'бумага',
#   'сказочный',
#   'город',
#   '14',
#   'листов',
#   '7',
#   'цветов'],
#  ['veld-co',
#   'цветная',
#   'бумага',
#   'самоклеящаяся',
#   '8',
#   'листов',
#   '8',
#   'цветов'],
#  ['апплика',
#   'альбом',
#   'для',
#   'рисования',
#   'цветы',
#   'скрапбукинг',
#   '20',
#   'листов'],
#  ['апплика', 'белый', 'картон', '8', 'листов'],
#  ['фабрика', 'фантазий', 'цветная', 'бумага', 'глиттерная', '5', 'листов'],
#  ...]

# %%
def lemmatize(text):
    words = text.split() # разбиваем текст на слова
    res = list()
    for word in words:
        p = morph.parse(word)[0]
        res.append(p.normal_form)

    return res

# %%
corpus = df["Название СТЕ"].str.lower().str.strip().to_list()

# %%
tokenized_corpus = df["Название СТЕ"].str.lower().str.strip().progress_apply(lambda t: lemmatize(t)).to_list()
# Out:
# 100%|██████████| 356573/356573 [04:38<00:00, 1280.01it/s]

# %%
morph = pymorphy2.MorphAnalyzer()
def clear_text(text: str):
    text = re.sub('[",*+!:;<=>?@]^_`{|}~]', '', text)
    text = re.sub('\s\d+\s', '', text)
    return text

def lemmatize(text):
    words = text.split() # разбиваем текст на слова
    res = list()
    for word in words:
        p = morph.parse(word)[0]
        nf = p.normal_form
        if nf not in res:
            res.append(nf)

    return res

# %%
df.shape
# Out:
# (356573, 9)

# %%
bm = BM25Model(prefit=False)

# %%
df = pd.read_feather("data/goods.feather")

# %%
df["text25"] = df["Название СТЕ"].str.lower().str.strip() + " " + df["Категория"].str.lower().str.strip()
tokenized_corpus  = df["text25"].progress_apply(lambda t: lemmatize(clear_text(t))).to_list()
# Out:
# 100%|██████████| 356575/356575 [08:00<00:00, 742.36it/s]

# %%
with open("tokenized_texts.json", "w") as fp:
     json.dump(tokenized_corpus, fp)

# %%
with open("tokenized_texts.json", "r") as fp:
    tokenized_corpus = json.load(fp)

# %%
np.save('tokenized_texts.npy', np.array(tokenized_corpus))    # .npy extension is added if not given
d = np.load('tokenized_texts.npy', allow_pickle=True)
np.array(tokenized_corpus) == d
# Out:
# /home/user/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   """Entry point for launching an IPython kernel.
# /home/user/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   This is separate from the ipykernel package so we can avoid doing imports until
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
len(d)
# Out:
# 356575

# %%
np.array(tokenized_corpus).save()
# Out:
# /home/user/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   """Entry point for launching an IPython kernel.
# array([list(['мяч', 'футбольный', 'mikasa', 'regateador5-g', 'мяч', 'футбольный']),
#        list(['мяч', 'волейбольный', 'gala', 'pro-linefivb', 'мяч', 'волейбольный']),
#        list(['мяч', 'волейбольный', 'mikasa', 'mva380k-obl', 'мяч', 'волейбольный']),
#        ...,
#        list(['обои', 'флизелиновый', 'под', 'покраска', 'nc', 'antivandal,', '(арт.4010-16),', '1,06*25', 'м', 'обои']),
#        list(['мусорный', 'ведро', 'kimberly-clark', 'aquarius', 'белый', 'пластиковое,ть', 'контейнер', 'и', 'другой', 'ёмкость', 'для', 'мусор', 'пластмассовый']),
#        list(['весы', 'cas', 'db-ii(е)', 'весы'])], dtype=object)

# %%
bm25 = BM25Okapi(tokenized_corpus)

# %%
query = "Солнцезащитные очки (!23)"
tokenized_query = lemmatize(clear_text(query))
tokenized_query
# Out:
# ['солнцезащитный', 'очки', '23']

# %%
doc_scores = bm25.get_scores(tokenized_query)

# %%
np.sum(np.array(doc_scores) > 0)
# Out:
# 356

# %%
df[df["cat_count"] == 1].iloc[-1]["Категория"]
# Out:
# 'Пластина для фиксации для черепно-лицевой хирургии, рассасывающаяся'

# %%
merged_lemm_corpus = [" ".join(words) for words in tokenized_corpus]

# %%
bm25.get_top_n(tokenized_query, merged_lemm_corpus, n=356)
# Out:
# ['очки солнцезащитный велосипедный с поляризация специальный экипировка для велоспорт',
#  'солнцезащитный система жалюзи оконный',
#  'солнцезащитный система жалюзи оконный',
#  'плёнка солнцезащитный джэжэ полимерный строительный материал',
#  'монтаж, установка, сборка солнцезащитный система прочее оборудование',
#  'изготовление солнцезащитный изделие из комбинация различный материал',
#  'монтаж, установка, сборка солнцезащитный система прочее оборудование',
#  'монтаж, установка, сборка солнцезащитный система прочее оборудование',
#  'очки защитный',
#  'очки защитный',
#  'очки защитный',
#  'очки защитный',
#  'очки защитный',
#  'очки защитный',
#  'очки защитный',
#  'защитный очки',
#  'очки защитный',
#  'очки защитный',
#  'очки защитный',
#  'очки защитный',
#  'очки защитный',
#  'очки защитный',
#  'очки защитный',
#  'очки защитный',
#  'защитный очки',
#  'очки защитный',
#  'очки защитный',
#  'очки защитный',
#  'рентгенозащитный очки',
#  'очки защитный',
#  'изготовление солнцезащитный система изделие из комбинация различный материал',
#  'крем biomatrix cream spfсредство для уход за кожа солнцезащитный',
#  'очки защитный медицинский',
#  'очки защитный открытый',
#  'очки защитный прозрачный',
#  'очки защитный визион',
#  'очки защитный открытый',
#  'очки защитный закрытый',
#  'очки защитный закрытый',
#  'очки защитный медицинский',
#  'очки ecolux защитный',
#  'защитный очки медицинский',
#  'очки защитный сибртех',
#  'очки i защитный',
#  'очки защитный открытый',
#  'очки визилюкс защитный',
#  'очки защитный инфинить',
#  'очки защитный исток',
#  'очки защитный медицинский',
#  'очки защитный закрытый',
#  'очки chimilux защитный',
#  'очки защитный медицинский',
#  'очки защитный открытый',
#  'очки защитный медицинский',
#  'очки росомзочка защитный',
#  'очки защитный закрытый',
#  'очки"универсал-титан-контраст" очки защитный',
#  'очки защитный закрытый',
#  'очки сибртехочка защитный',
#  'очки защитный открытый',
#  'очки дымчатый защитный',
#  'очки защитныеfubag защитный',
#  'очки защитный медицинский',
#  'очки слесарный защитный',
#  'очки защитный медицинский',
#  'монтаж система вертикальный солнцезащитный жалюзи монтаж, установка, сборка прочее оборудование',
#  'очки защитный открытый исток',
#  'очки защитный тип люцерн',
#  'очки jsp галактус защитный',
#  'очки i-spector вернона защитный',
#  'очки "люцерна" (прозрачные) защитный',
#  'очки защитный закрытый прозрачныеочка',
#  'очки «ай-во» (9160285) защитный',
#  'очки защитный открытый медицинский',
#  'очки «классик» (9305514) защитный',
#  'очки закрытый зппанорама,очка защитный',
#  'очки uvex спортстайлочка защитный',
#  'очки защитный зп2 panorama',
#  'очки optex визя защитный',
#  'очки защитный safety goggles',
#  'очки защитный закрытый тип',
#  'очки защитный "люцерна", прозрачный',
#  'очки optex визя защитный',
#  'очки защитный открытый тип',
#  'очки «ай-воркс» (9194175) защитный',
#  'очки защитный для электрика',
#  'очки открытый люцерн защитный',
#  'очки защитный "люцерна", прозрачный',
#  'очки «монолюкс» (60590) защитный',
#  'очки "люцерна" (прозрачные) защитный',
#  'очки затемнить бибер защитный',
#  'очки защитный сибртех поликарбонат',
#  'очки открытый 3m защитный',
#  'очки i-spector лестер защитный',
#  'очки защитные, коррегирующие, защитный',
#  'очки «ультравижн» (9301105) защитный',
#  'очки защитный панорамный kraftoolочка',
#  'очки защитный открытый тип',
#  'очки uvex ай-3рег.уг.накл. защитный',
#  'очки защитный зн-22 медицинский',
#  'очки защитный открытый нбт1',
#  'очки uvex ая-ворксочок защитный',
#  'очки защитный закрытый тип',
#  'очки защитный профи бибер',
#  'очки защитный открытый start',
#  'защитный очки 3m™ visitor',
#  'очки защитный закрытый прозрачныеочка',
#  'очки «визилюкс» (60401) защитный',
#  'защитный очки открытый тип',
#  'очки защитный закрытый тип',
#  'очки защитныеsurgut арт.очки защитный',
#  'изготовление горизонтальный солнцезащитный жалюзи для окно изделие из комбинация различный материал',
#  'очки защитный открытый start (союзспецодежда)',
#  'очки зашитный uvex ультравижночка защитный',
#  'очки защитный с прямой вентиляция',
#  'очки «ай-воркс» янтарный (9194365) защитный',
#  'защитный очки-экран biot (17840) очки',
#  'экран защитный «кристидент» очки медицинский',
#  'очки закрытый uvex ультравижночка защитный',
#  'очки защитный прозрачный с дужка',
#  'очки i-spector неллор 131-0304-01 защитный',
#  'очки защитный с дужка курс',
#  'очки герметичный исток панорама защитный',
#  'очки защитный с прямой вентиляция',
#  'очки для тренировка дриблинг экипировка',
#  'спецодежда (экипировка) очки"универсал-титан" очки защитный',
#  'очки открытый люцерна, прозрачные,очка защитный',
#  'очки закрытый росомза панорама защитный',
#  'очки защитный fit расходный материал',
#  'очки закрытый ампаро™ венус, защитный',
#  'спецодежда (специальный экипировка) очки защитный',
#  'очки дополнить реальность microsoft hololensочка',
#  'очки защитный открытый тип сибртехочка',
#  'очки защитный росомза orama strongglassочка',
#  'очки защитный исток очк-001 прозрачный',
#  'очки 3m solus s1201sgaf-eu защитный',
#  'очки виртуальный реальность oculus questочки',
#  'очки защитный профи с антизапотевание',
#  'очки открытый люцерна, прозрачный защитный',
#  'очки защитный открытый о45 визион',
#  'изготовление система вертикальный солнцезащитный жалюзи для окно изделие из комбинация различный материал',
#  'лёгкий увлажнять крем-гель для лицо spf 15,мл., кодkora средство уход за кожа солнцезащитный',
#  'плёнка зеркальный солнцезащитный solarblock silver 25, ширина 1,52 м, 30м полимерный строительный материал',
#  'очки защитный hmx-01 с клапан вентиляция',
#  'мышь - очки компьютерные, glassouse компьютерный',
#  'очки для газосварщик г-2 (зн-56) защитный',
#  'очки росомза о50 монако стронггласспрозрачный защитный',
#  'очки корригировать устройство для коррекция слабовидение',
#  'очки открытый о35 визион (pl),очки защитный',
#  'очки корригировать устройство для коррекция слабовидение',
#  'очки закрытый росомза зн11 panoramaочка защитный',
#  'очки защитный открытый о35 визион (pl)очки',
#  'очки защитный открытый поликарбонатный "люцерна" прозрачный',
#  'очки газосварочный винтовой аппарат сварочный прочий',
#  'очки защитный открытый 3м secure fitочки',
#  'очки santarelli устройство для коррекция слабовидение',
#  'очки 3m sf401sgafkt-blu-eu с обтюратор защитный',
#  'очки корригировать устройство для коррекция слабовидение',
#  'очки hammer pg01 одежда и защита',
#  'очки закрытый с непрямой вентиляцией,очка защитный',
#  'очки закрытый росомза зп2 panoramaочка защитный',
#  'очки корригировать устройство для коррекция слабовидение',
#  'очки корригировать устройство для коррекция слабовидение',
#  'очки закрытый optex кемь плюс защитный',
#  'очки сварщик toba3t5 delta plus защитный',
#  'очки защитные, с непрямой вентиляция защитный',
#  'очки защитный sf401xsgaf-blu xa006509047 3m id3m',
#  'очки для дриблинг pure2improve p2i100260 экипировка',
#  'очки uvex феос сх2257 прозрачный защитный',
#  'очки защитный открытый универсальный рим р1',
#  'очки корригировать устройство для коррекция слабовидение',
#  'очки лазерный ada laser glasses защитный',
#  'очки корригировать устройство для коррекция слабовидение',
#  'спецодежда (экипировка) очки "сургут" прозрачный защитный',
#  'очки закрытый росомза зн11 panorama21111 защитный',
#  'очки закрытые, с прямой вентиляция защитный',
#  'спецодежда (экипировка) очки "перспектаz" прозрачный защитный',
#  'очки защитный закрытый зн4 эталон арт.очки',
#  'очки защитный закрытый зп8 эталон арт.очки',
#  'очки корригировать устройство для коррекция слабовидение',
#  'очки защитный закрытый 3h11 super panorama',
#  'очки bravaclear принадлежность для косметический процедура',
#  'очки jsp галактус покрытие kn защитный',
#  'очки корригировать устройство для коррекция слабовидение',
#  'очки защитный незапотевать жёлтый krafter, поликарбонат',
#  'очки знг1 panorama super (pc) защитный',
#  'очки 3m securefit sf201af-eu прозрачный защитный',
#  'очки корригировать устройство для коррекция слабовидение',
#  'очки защитный зн11 super panorama с обтюратор',
#  'очки виртуальный реальность прочий система отображение информация',
#  'очки для защита от рентгеновский излучение рентгенозащитный',
#  'очки закрытый росомза зн11 panorama superочки защитный',
#  'очки пластмассовый tempo устройство для коррекция слабовидение',
#  'очки пластмассовый tempo устройство для коррекция слабовидение',
#  'защитный открытый очки gigant style tech gg-006',
#  'очки корригировать nikitana устройство для коррекция слабовидение',
#  'очки открытый "ай-во" uvex (9160285) прозрачный защитный',
#  'очки uvex феос прозрачные, артикул производителя225 защитный',
#  'очки защитный прочий расходный материал медицинский назначение',
#  'очки закрытый зн55 spark super (pc)очки защитный',
#  'очки корригировать nikitana устройство для коррекция слабовидение',
#  'очки закрытый росомза зн11 super panorama защитный',
#  'спецодежда (специальный экипировка) очки"визион" защитный прозрачный очки',
#  'очки защитный открытый поликарбонатный тип "люцерна" очк304',
#  'очки jsp стелс 16г лин. серый защитный',
#  'очки тип "люцерна" прозрачный с дужка защитный',
#  'спецодежда (экипировка) очки супер панорама прозрачный защитный',
#  'очки защитный прозрачный открытый прочий хозяйственный товар',
#  'очки пластмассовый tempo устройство для коррекция слабовидение',
#  'очки 3m peltor virtua ap 71512-00000м защитный',
#  'очки корригировать tempo устройство для коррекция слабовидение',
#  'спецодежда (специальный экипировка) очки зн11 "панорама" защитный',
#  'защитный очки открытый тип классик тим жёлтый',
#  'очки uvex феос cx2 соникочка защитный медицинский',
#  'очки 0,3 пласмас устройство для коррекция слабовидение',
#  'очки металлический tempo устройство для коррекция слабовидение',
#  'очки защитный открытый о37 «universal titan» (13713)',
#  'мягкий игрушка «ёжик колюнчик» в очки прочий',
#  'очки защитный закрытый газосварщик росомза знд2 admiral(23232)',
#  'очки росомза универсал титан о37 прозрачный защитный',
#  'очки защитный открытый росомзsurgut прозрачный (арт произвый 18840)',
#  'спецодежда (специальный экипировка) очки hammer profi прозрачный защитный',
#  'очки защитный закрытый зп2 панорама с прямой вентиляция',
#  'очки защитный прозрачный прочий расходный материал медицинский назначение',
#  'dji fpv очки goggles digital прочий компьютерный комплектующие',
#  'система виртуальный реальность htc vive focus plus очки',
#  'очки защитный закрытый ампарый венуспрозрачный (арт произвый 221319)',
#  'спецодежда (специальный экипировка) очки "хаммер" открытый дымчатый защитный',
#  'спецодежда (экипировка) очки защитный закрытый с непрямой вентиляция',
#  'очки защитный закрытый универсальный рим р2 нв прозрачный',
#  'очки корригировать пластмассовый merel устройство для коррекция слабовидение',
#  'очки для газосварщик дуга г-2 аппарат сварочный прочий',
#  'очки защитный закрытый зн11 panorama с непрямой вентиляция',
#  'очки защитный открытый 3м securefitпрозрачный (арт произвый sf401af-eu)',
#  'открытый очки росомза о50 monaco super (15030) защитный',
#  'очки защитный закрытый с непрямой вентиляция зн4 эталон strongglass™ (2c-1,2 pc)',
#  'очки защитный компьютерный росомза о13 favori office st дптр +1,0 (11319/10)',
#  'щиток защитный uvex на всё очки ультравижн (арт произвый 9301.317) лицевой',
#  'очки закрытый зн55 spark strongglass™ (спарк стронг гласс) бесцветный (25537) защитный',
#  'очки для газосварщик сибинодежда специальный защита от термический риск электрический дуга',
#  'очки для газосварка одежда специальный защита от термический риск электрический дуга',
#  'очки защитный открытый 3м led light vision прозрачный (арт пр 11356-00000m)',
#  'защитный закрытый очки с прямой вентиляция росомза зп2 panorama super pcочки',
#  'очки открытый защитный из поликарбонат 3m™ solus™, с усиленный покрытие scotchgard™',
#  'очки защитный открытый росомза о15 hammer active прозрачный (арт пр 11530)',
#  'очки защитный закрытый росомза зп2 super panorama затемнить (арт пр 30228)',
#  'защитный гелиевый очки атлантпрочий оборудование и инвентарь для санитарный технический содержание',
#  'очки защитный открытый материал из полимер и пластмасса для товар культура искусство',
#  'закрытый защитный очки росомза зп2 panoramaс прямой вентиляция специальный экипировка, кроме спецодежда',
#  'очки о15 hammer active super (хаммера актив супер) (pc) (11530) прозрачный защитный',
#  'очки для газосварщик дуга г-2 зн-56одежда специальный защита от термический риск электрический',
#  'открытый защитный очки, прозрачные, с покрытие as/af против царапина и запотевание очки',
#  'протектор для защита глаз natus billiband: стандартный billiband regular очки фототерапия новорождённый',
#  'очки корригировать по индивидуальный рецепту. модель g56351 c233 устройство для коррекция слабовидение',
#  'протектор для защита глаз natus billiband:размер "микро" biliband micro очки фототерапия новорождённый',
#  'очки для плавание speedo futura classic голубой линза экипировка водный вид спорт',
#  'знак безопасность m01 работать в защитный очки (плёнка,200х200) стенды, таблички, карман информационный',
#  'очки защитный для газосварщик одежда специальный защита от термический риск электрический дуга',
#  'очки виртуальный реальность htc vive pro расходный материал и зип к периферийный устройство',
#  'очки виртуальный реальность smarterra vr, с джойстиком,, белый [3dsmarvr] прочий система отображение информация',
#  'очки стрелковый защитный gen 1, затемнить оборудование и инвентарь для вид спорт прочее',
#  'протектор для защита глаз новорождённый ребёнок при проведение фототерапия (упаковкаштук) средний размер очки',
#  'очки для газосварщик дуга г-2 зн-56 (7290040) одежда специальный защита от термический риск электрический',
#  'очки защитный открытый типа, прозрачные, ударопрочный для огэ/гиа по химия расходный материал учебный оборудование',
#  'защитный герметичный очки для работа с агрессивный и не жидкость росомза знг1 super panorama caочки',
#  'полумаска с очки elipse integra a1p3 раз m/l средний/больша (spr401ifuс) средство индивидуальный защита орган дыхание',
#  'протектор для защита глаз новорождённый ребёнок при проведение фототерапия (упаковкаштук) billiband micro малый размер очки',
#  'экран защитный для лицо «классик специальный» свой корригировать очко с помощь 2-й клипонов. (зажим-крепление) очки медицинский',
#  'спецодежда (экипировка); защитный свойство от механический воздействия, абразива, брызги раствор кислота и щелочей, уф-излучения; очки; пластик (пбт)/поликарбонат/высокотемпературный полиуретан (tpu) очки']

# %%
morph = pymorphy2.MorphAnalyzer()
